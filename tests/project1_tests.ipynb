# %%
#imports
import re

import heapq

# %%
#strip and ingest text file
file = open('p1_graph.txt', 'r')
Lines = file.readlines()

for line in Lines:
    if "Vertices" in line:
        vert_start = Lines.index(line)
        
    if "Edges" in line:
        edge_start = Lines.index(line)
        vert_end = Lines.index(line) -1
    if "Source" in line:
        edge_end = Lines.index(line) -1
        source = Lines[(Lines.index(line) +1)].strip().split(',')[1]
        dest = Lines[(Lines.index(line) +2)].strip().split(',')[1]
        
verts = Lines[vert_start:vert_end]
edges = Lines[edge_start:edge_end]

# %%
dest, source
# Out:
# ('99', '0')

# %%
#parse out the information for the locations of each vertex 
#within the larger 10x10 square
vertID_squareLoc_dict = {}

for elem in verts:
    if not re.search('[a-zA-Z]', elem):
        #remove newline charecter
        elem = elem.strip()
        elem_split = elem.split(',')
        
        #assign each vertexID as the key, and it's location value in the 10x10
        vertID_squareLoc_dict[elem_split[0]] = elem_split[1]
        
vertID_squareLoc_dict
# Out:
# {'0': '79',
#  '1': '28',
#  '2': '77',
#  '3': '29',
#  '4': '42',
#  '5': '30',
#  '6': '38',
#  '7': '31',
#  '8': '56',
#  '9': '78',
#  '10': '8',
#  '11': '34',
#  '12': '46',
#  '13': '99',
#  '14': '16',
#  '15': '93',
#  '16': '3',
#  '17': '25',
#  '18': '28',
#  '19': '75',
#  '20': '41',
#  '21': '19',
#  '22': '75',
#  '23': '69',
#  '24': '59',
#  '25': '1',
#  '26': '13',
#  '27': '8',
#  '28': '36',
#  '29': '97',
#  '30': '89',
#  '31': '77',
#  '32': '86',
#  '33': '71',
#  '34': '99',
#  '35': '29',
#  '36': '67',
#  '37': '23',
#  '38': '88',
#  '39': '84',
#  '40': '67',
#  '41': '64',
#  '42': '30',
#  '43': '53',
#  '44': '32',
#  '45': '40',
#  '46': '0',
#  '47': '66',
#  '48': '62',
#  '49': '44',
#  '50': '77',
#  '51': '2',
#  '52': '28',
#  '53': '94',
#  '54': '80',
#  '55': '37',
#  '56': '5',
#  '57': '56',
#  '58': '53',
#  '59': '89',
#  '60': '7',
#  '61': '66',
#  '62': '54',
#  '63': '74',
#  '64': '29',
#  '65': '81',
#  '66': '7',
#  '67': '97',
#  '68': '49',
#  '69': '78',
#  '70': '70',
#  '71': '85',
#  '72': '77',
#  '73': '78',
#  '74': '0',
#  '75': '19',
#  '76': '47',
#  '77': '98',
#  '78': '19',
#  '79': '32',
#  '80': '12',
#  '81': '19',
#  '82': '28',
#  '83': '91',
#  '84': '1',
#  '85': '81',
#  '86': '50',
#  '87': '63',
#  '88': '56',
#  '89': '72',
#  '90': '49',
#  '91': '64',
#  '92': '63',
#  '93': '35',
#  '94': '81',
#  '95': '20',
#  '96': '29',
#  '97': '22',
#  '98': '94',
#  '99': '17'}

# %%
#create an adjacency dictionary of dictionaries for each vertex
vertex_adj_dict = {}

#temporary list to strip out elements to be added to dict
temp_list = []
for elem in edges:
    if not re.search('[a-zA-Z]', elem):
        #remove newline charecter
        elem = elem.strip()
        elem_split = elem.split(',')
        temp_list.append(elem_split)

temp_list
# Out:
# [['0', '2', '1218'],
#  ['0', '9', '324'],
#  ['0', '14', '6247'],
#  ['0', '22', '4069'],
#  ['0', '24', '1408'],
#  ['0', '25', '10401'],
#  ['0', '27', '6424'],
#  ['0', '28', '4683'],
#  ['0', '31', '1863'],
#  ['0', '40', '1784'],
#  ['0', '52', '4759'],
#  ['0', '56', '7436'],
#  ['0', '61', '2734'],
#  ['0', '64', '4481'],
#  ['0', '70', '8440'],
#  ['0', '71', '3979'],
#  ['0', '73', '863'],
#  ['0', '76', '3133'],
#  ['0', '82', '4494'],
#  ['0', '91', '4528'],
#  ['0', '94', '7572'],
#  ['0', '99', '6157'],
#  ['1', '14', '2316'],
#  ['1', '16', '5720'],
#  ['1', '29', '7370'],
#  ['1', '33', '9203'],
#  ['1', '42', '7994'],
#  ['1', '54', '10570'],
#  ['1', '55', '1479'],
#  ['1', '56', '3402'],
#  ['1', '61', '4655'],
#  ['1', '62', '5523'],
#  ['1', '64', '476'],
#  ['1', '69', '5036'],
#  ['1', '74', '8152'],
#  ['1', '85', '9284'],
#  ['1', '88', '3721'],
#  ['1', '94', '9303'],
#  ['2', '19', '2719'],
#  ['2', '28', '4229'],
#  ['2', '30', '2583'],
#  ['2', '34', '2754'],
#  ['2', '35', '5122'],
#  ['2', '37', '6361'],
#  ['2', '46', '10363'],
#  ['2', '47', '1964'],
#  ['2', '54', '7914'],
#  ['2', '56', '7031'],
#  ['2', '59', '1338'],
#  ['2', '75', '6229'],
#  ['2', '77', '2223'],
#  ['2', '79', '6606'],
#  ['2', '83', '7179'],
#  ['2', '90', '3464'],
#  ['2', '92', '4567'],
#  ['2', '94', '6367'],
#  ['2', '98', '4019'],
#  ['3', '15', '8713'],
#  ['3', '37', '5748'],
#  ['3', '46', '9509'],
#  ['3', '49', '5563'],
#  ['3', '53', '8121'],
#  ['3', '54', '11199'],
#  ['3', '61', '4932'],
#  ['3', '66', '3617'],
#  ['3', '70', '10100'],
#  ['3', '73', '5076'],
#  ['3', '76', '2581'],
#  ['3', '88', '4291'],
#  ['3', '89', '8585'],
#  ['3', '91', '6292'],
#  ['3', '99', '2767'],
#  ['4', '5', '2490'],
#  ['4', '9', '6983'],
#  ['4', '11', '1958'],
#  ['4', '26', '3843'],
#  ['4', '35', '7518'],
#  ['4', '38', '7230'],
#  ['4', '53', '5434'],
#  ['4', '56', '5412'],
#  ['4', '61', '4588'],
#  ['4', '66', '6770'],
#  ['4', '67', '7253'],
#  ['4', '72', '6399'],
#  ['4', '88', '3721'],
#  ['4', '89', '2892'],
#  ['4', '90', '6943'],
#  ['4', '94', '3978'],
#  ['4', '95', '2653'],
#  ['4', '96', '7517'],
#  ['5', '27', '8471'],
#  ['5', '29', '9663'],
#  ['5', '38', '9662'],
#  ['5', '43', '3452'],
#  ['5', '49', '4638'],
#  ['5', '55', '7527'],
#  ['5', '67', '9640'],
#  ['5', '74', '3908'],
#  ['5', '81', '9360'],
#  ['5', '83', '5792'],
#  ['5', '84', '3687'],
#  ['5', '85', '5029'],
#  ['5', '86', '2126'],
#  ['5', '87', '4580'],
#  ['5', '89', '4545'],
#  ['5', '96', '9606'],
#  ['6', '12', '2335'],
#  ['6', '13', '6461'],
#  ['6', '19', '5110'],
#  ['6', '29', '6465'],
#  ['6', '31', '3997'],
#  ['6', '35', '1319'],
#  ['6', '37', '4746'],
#  ['6', '40', '2938'],
#  ['6', '44', '6405'],
#  ['6', '45', '7937'],
#  ['6', '50', '4615'],
#  ['6', '53', '7045'],
#  ['6', '57', '2661'],
#  ['6', '76', '1406'],
#  ['6', '77', '6127'],
#  ['6', '86', '8465'],
#  ['6', '87', '5689'],
#  ['6', '89', '7359'],
#  ['6', '92', '5894'],
#  ['7', '16', '3660'],
#  ['7', '17', '3769'],
#  ['7', '20', '1541'],
#  ['7', '21', '7256'],
#  ['7', '22', '5327'],
#  ['7', '25', '2678'],
#  ['7', '27', '6512'],
#  ['7', '28', '4826'],
#  ['7', '29', '8650'],
#  ['7', '33', '4541'],
#  ['7', '34', '9747'],
#  ['7', '37', '2237'],
#  ['7', '42', '1146'],
#  ['7', '51', '2850'],
#  ['7', '56', '4788'],
#  ['7', '65', '4969'],
#  ['7', '66', '6266'],
#  ['7', '68', '7700'],
#  ['7', '78', '7997'],
#  ['7', '80', '1810'],
#  ['7', '89', '4353'],
#  ['7', '93', '3563'],
#  ['8', '10', '6135'],
#  ['8', '21', '4683'],
#  ['8', '24', '2747'],
#  ['8', '25', '7661'],
#  ['8', '36', '948'],
#  ['8', '42', '6446'],
#  ['8', '55', '2688'],
#  ['8', '58', '3656'],
#  ['8', '62', '2306'],
#  ['8', '66', '5877'],
#  ['8', '68', '3356'],
#  ['8', '77', '3933'],
#  ['8', '80', '5904'],
#  ['8', '87', '2962'],
#  ['8', '88', '1078'],
#  ['8', '93', '2719'],
#  ['8', '94', '5660'],
#  ['8', '98', '4028'],
#  ['8', '99', '4577'],
#  ['9', '18', '4669'],
#  ['9', '20', '8257'],
#  ['9', '44', '7470'],
#  ['9', '45', '8513'],
#  ['9', '46', '10961'],
#  ['9', '48', '6456'],
#  ['9', '53', '4441'],
#  ['9', '54', '8810'],
#  ['9', '57', '2895'],
#  ['9', '59', '789'],
#  ['9', '73', '643'],
#  ['9', '80', '8347'],
#  ['9', '86', '8456'],
#  ['9', '95', '9516'],
#  ['10', '17', '3949'],
#  ['10', '21', '1670'],
#  ['10', '26', '5039'],
#  ['10', '30', '8765'],
#  ['10', '31', '7141'],
#  ['10', '35', '2317'],
#  ['10', '53', '10024'],
#  ['10', '66', '1592'],
#  ['10', '78', '1568'],
#  ['10', '85', '11030'],
#  ['11', '14', '3312'],
#  ['11', '22', '3982'],
#  ['11', '38', '6676'],
#  ['11', '45', '3402'],
#  ['11', '48', '3506'],
#  ['11', '50', '5667'],
#  ['11', '51', '3876'],
#  ['11', '52', '5060'],
#  ['11', '54', '6323'],
#  ['11', '60', '4020'],
#  ['11', '62', '2263'],
#  ['11', '80', '2480'],
#  ['11', '83', '6486'],
#  ['11', '91', '3006'],
#  ['11', '94', '5439'],
#  ['11', '96', '5634'],
#  ['11', '97', '1568'],
#  ['12', '14', '2414'],
#  ['12', '16', '4855'],
#  ['12', '19', '3430'],
#  ['12', '22', '3751'],
#  ['12', '29', '5927'],
#  ['12', '31', '3328'],
#  ['12', '33', '6398'],
#  ['12', '34', '6457'],
#  ['12', '36', '2876'],
#  ['12', '46', '6977'],
#  ['12', '51', '5646'],
#  ['12', '56', '3418'],
#  ['12', '68', '3226'],
#  ['12', '69', '4006'],
#  ['12', '71', '4365'],
#  ['12', '72', '4217'],
#  ['12', '83', '7590'],
#  ['12', '87', '3526'],
#  ['12', '95', '6068'],
#  ['12', '97', '3791'],
#  ['12', '98', '5611'],
#  ['13', '25', '12228'],
#  ['13', '26', '10111'],
#  ['13', '30', '1159'],
#  ['13', '32', '3342'],
#  ['13', '36', '3699'],
#  ['13', '39', '4803'],
#  ['13', '42', '10640'],
#  ['13', '46', '13081'],
#  ['13', '49', '6834'],
#  ['13', '51', '11900'],
#  ['13', '56', '9814'],
#  ['13', '59', '1839'],
#  ['13', '60', '9144'],
#  ['13', '66', '9915'],
#  ['13', '76', '5540'],
#  ['13', '81', '8413'],
#  ['13', '83', '8167'],
#  ['13', '96', '7303'],
#  ['14', '16', '3408'],
#  ['14', '20', '6280'],
#  ['14', '23', '5338'],
#  ['14', '26', '2648'],
#  ['14', '27', '1550'],
#  ['14', '32', '6866'],
#  ['14', '37', '2737'],
#  ['14', '44', '4914'],
#  ['14', '46', '6180'],
#  ['14', '67', '7900'],
#  ['14', '69', '6152'],
#  ['14', '70', '8306'],
#  ['14', '76', '3122'],
#  ['14', '78', '3139'],
#  ['14', '82', '2187'],
#  ['14', '83', '9613'],
#  ['14', '86', '7438'],
#  ['15', '16', '9060'],
#  ['15', '18', '8262'],
#  ['15', '23', '6123'],
#  ['15', '26', '7865'],
#  ['15', '29', '4060'],
#  ['15', '31', '4150'],
#  ['15', '41', '3108'],
#  ['15', '43', '4072'],
#  ['15', '50', '4332'],
#  ['15', '51', '8800'],
#  ['15', '52', '8446'],
#  ['15', '62', '3227'],
#  ['15', '63', '1755'],
#  ['15', '68', '7696'],
#  ['15', '75', '9693'],
#  ['15', '77', '4755'],
#  ['15', '85', '2003'],
#  ['15', '87', '2654'],
#  ['15', '89', '1831'],
#  ['15', '92', '2729'],
#  ['15', '93', '5850'],
#  ['15', '95', '6945'],
#  ['15', '96', '8832'],
#  ['15', '98', '844'],
#  ['16', '32', '8847'],
#  ['16', '38', '10035'],
#  ['16', '42', '4400'],
#  ['16', '44', '4050'],
#  ['16', '48', '6899'],
#  ['16', '57', '6143'],
#  ['16', '60', '3544'],
#  ['16', '65', '8462'],
#  ['16', '68', '7304'],
#  ['16', '78', '6348'],
#  ['16', '80', '1852'],
#  ['16', '82', '5584'],
#  ['16', '89', '7642'],
#  ['16', '98', '9304'],
#  ['17', '30', '7943'],
#  ['17', '31', '5163'],
#  ['17', '39', '5804'],
#  ['17', '43', '3544'],
#  ['17', '47', '3925'],
#  ['17', '52', '3399'],
#  ['17', '69', '5850'],
#  ['17', '74', '5154'],
#  ['17', '85', '7341'],
#  ['17', '92', '4522'],
#  ['17', '98', '7042'],
#  ['18', '39', '6758'],
#  ['18', '42', '7993'],
#  ['18', '44', '6636'],
#  ['18', '48', '7605'],
#  ['18', '56', '3454'],
#  ['18', '57', '3365'],
#  ['18', '58', '6331'],
#  ['18', '60', '2375'],
#  ['18', '62', '5479'],
#  ['18', '63', '6515'],
#  ['18', '67', '6860'],
#  ['18', '73', '5176'],
#  ['18', '75', '1462'],
#  ['18', '77', '6948'],
#  ['18', '82', '451'],
#  ['18', '93', '3389'],
#  ['18', '97', '5997'],
#  ['19', '21', '6570'],
#  ['19', '28', '4242'],
#  ['19', '30', '5042'],
#  ['19', '34', '4679'],
#  ['19', '63', '751'],
#  ['19', '64', '5881'],
#  ['19', '73', '3249'],
#  ['19', '75', '7265'],
#  ['19', '76', '3707'],
#  ['19', '78', '7246'],
#  ['19', '79', '4658'],
#  ['19', '92', '1959'],
#  ['20', '22', '5046'],
#  ['20', '26', '4433'],
#  ['20', '31', '6796'],
#  ['20', '35', '8732'],
#  ['20', '36', '6567'],
#  ['20', '38', '8402'],
#  ['20', '39', '5147'],
#  ['20', '44', '1369'],
#  ['20', '53', '6289'],
#  ['20', '54', '4246'],
#  ['20', '55', '6596'],
#  ['20', '73', '8062'],
#  ['20', '75', '8939'],
#  ['20', '77', '8835'],
#  ['20', '78', '9182'],
#  ['20', '82', '7519'],
#  ['20', '87', '3315'],
#  ['20', '95', '1752'],
#  ['21', '25', '8025'],
#  ['21', '38', '7054'],
#  ['21', '39', '7505'],
#  ['21', '53', '8577'],
#  ['21', '55', '2124'],
#  ['21', '59', '6105'],
#  ['21', '63', '7251'],
#  ['21', '69', '5683'],
#  ['21', '72', '6151'],
#  ['21', '73', '5893'],
#  ['21', '77', '7664'],
#  ['21', '82', '1179'],
#  ['21', '83', '10989'],
#  ['21', '90', '2250'],
#  ['21', '92', '7114'],
#  ['21', '93', '3924'],
#  ['21', '96', '815'],
#  ['22', '26', '6429'],
#  ['22', '27', '7184'],
#  ['22', '36', '2279'],
#  ['22', '41', '1300'],
#  ['22', '48', '2798'],
#  ['22', '49', '2705'],
#  ['22', '52', '6318'],
#  ['22', '53', '1911'],
#  ['22', '55', '4808'],
#  ['22', '59', '4033'],
#  ['22', '62', '1751'],
#  ['22', '73', '3341'],
#  ['22', '80', '6391'],
#  ['22', '82', '5705'],
#  ['22', '84', '7682'],
#  ['22', '91', '993'],
#  ['22', '93', '4034'],
#  ['22', '95', '6612'],
#  ['22', '97', '5277'],
#  ['22', '98', '1860'],
#  ['22', '99', '6515'],
#  ['23', '24', '553'],
#  ['23', '46', '10556'],
#  ['23', '60', '5742'],
#  ['23', '62', '4699'],
#  ['23', '64', '3512'],
#  ['23', '75', '5060'],
#  ['23', '95', '9348'],
#  ['24', '27', '5144'],
#  ['24', '28', '3771'],
#  ['24', '36', '2361'],
#  ['24', '37', '6523'],
#  ['24', '40', '1734'],
#  ['24', '42', '9025'],
#  ['24', '44', '7535'],
#  ['24', '50', '2626'],
#  ['24', '51', '9273'],
#  ['24', '53', '5699'],
#  ['24', '56', '6379'],
#  ['24', '64', '3121'],
#  ['24', '66', '6180'],
#  ['24', '67', '3824'],
#  ['24', '71', '4756'],
#  ['24', '72', '2567'],
#  ['25', '30', '12092'],
#  ['25', '34', '12139'],
#  ['25', '41', '6724'],
#  ['25', '42', '2703'],
#  ['25', '46', '859'],
#  ['25', '56', '4796'],
#  ['25', '58', '5121'],
#  ['25', '59', '10821'],
#  ['25', '71', '8612'],
#  ['25', '74', '730'],
#  ['25', '81', '8006'],
#  ['25', '86', '5183'],
#  ['25', '90', '8849'],
#  ['26', '31', '6841'],
#  ['26', '33', '7117'],
#  ['26', '46', '3562'],
#  ['26', '51', '2148'],
#  ['26', '58', '4326'],
#  ['26', '63', '6416'],
#  ['26', '66', '3531'],
#  ['26', '67', '9064'],
#  ['26', '71', '7152'],
#  ['26', '73', '7923'],
#  ['26', '78', '5770'],
#  ['26', '79', '2488'],
#  ['26', '85', '7687'],
#  ['26', '89', '6526'],
#  ['26', '95', '3988'],
#  ['26', '97', '2030'],
#  ['26', '98', '8074'],
#  ['26', '99', '3357'],
#  ['27', '29', '8830'],
#  ['27', '32', '7696'],
#  ['27', '34', '8922'],
#  ['27', '38', '7933'],
#  ['27', '40', '5250'],
#  ['27', '44', '6463'],
#  ['27', '49', '5247'],
#  ['27', '56', '2142'],
#  ['27', '64', '2132'],
#  ['27', '86', '8964'],
#  ['27', '90', '3402'],
#  ['27', '91', '6572'],
#  ['27', '92', '7020'],
#  ['28', '33', '7153'],
#  ['28', '48', '5592'],
#  ['28', '63', '4835'],
#  ['28', '64', '2394'],
#  ['28', '65', '7162'],
#  ['28', '66', '3228'],
#  ['28', '71', '5163'],
#  ['28', '74', '6645'],
#  ['28', '80', '4389'],
#  ['28', '81', '2985'],
#  ['28', '90', '2662'],
#  ['28', '91', '3939'],
#  ['28', '92', '4466'],
#  ['29', '33', '6760'],
#  ['29', '34', '1533'],
#  ['29', '37', '8260'],
#  ['29', '38', '1088'],
#  ['29', '50', '1853'],
#  ['29', '55', '6395'],
#  ['29', '57', '4590'],
#  ['29', '62', '5012'],
#  ['29', '69', '2360'],
#  ['29', '73', '2200'],
#  ['29', '74', '11827'],
#  ['29', '76', '5286'],
#  ['29', '81', '8500'],
#  ['29', '85', '6059'],
#  ['29', '92', '5366'],
#  ['29', '93', '6619'],
#  ['30', '45', '10192'],
#  ['30', '47', '4547'],
#  ['30', '61', '4170'],
#  ['30', '66', '9212'],
#  ['30', '67', '2162'],
#  ['30', '76', '4962'],
#  ['30', '80', '10326'],
#  ['30', '84', '11657'],
#  ['30', '90', '4847'],
#  ['30', '91', '5771'],
#  ['30', '92', '6988'],
#  ['30', '98', '5568'],
#  ['31', '32', '1674'],
#  ['31', '36', '457'],
#  ['31', '40', '1065'],
#  ['31', '42', '7543'],
#  ['31', '44', '6107'],
#  ['31', '47', '1383'],
#  ['31', '73', '1268'],
#  ['31', '79', '6009'],
#  ['31', '85', '5795'],
#  ['31', '87', '3610'],
#  ['31', '94', '5775'],
#  ['32', '35', '6846'],
#  ['32', '42', '7418'],
#  ['32', '47', '2292'],
#  ['32', '48', '4150'],
#  ['32', '53', '1583'],
#  ['32', '55', '5229'],
#  ['32', '67', '1907'],
#  ['32', '68', '5419'],
#  ['32', '71', '935'],
#  ['32', '73', '2333'],
#  ['32', '85', '4541'],
#  ['32', '86', '6269'],
#  ['32', '88', '3365'],
#  ['32', '90', '5292'],
#  ['32', '92', '3445'],
#  ['32', '99', '7126'],
#  ['33', '38', '7163'],
#  ['33', '51', '7372'],
#  ['33', '55', '7726'],
#  ['33', '60', '8937'],
#  ['33', '63', '3413'],
#  ['33', '66', '9821'],
#  ['33', '70', '505'],
#  ['33', '71', '4173'],
#  ['33', '72', '6712'],
#  ['33', '73', '7281'],
#  ['33', '75', '10455'],
#  ['33', '76', '7327'],
#  ['33', '82', '8713'],
#  ['33', '84', '7194'],
#  ['33', '86', '1991'],
#  ['33', '92', '2724'],
#  ['33', '94', '1034'],
#  ['33', '96', '9878'],
#  ['33', '97', '5172'],
#  ['34', '41', '5520'],
#  ['34', '46', '12993'],
#  ['34', '47', '4584'],
#  ['34', '52', '7289'],
#  ['34', '55', '6621'],
#  ['34', '62', '6127'],
#  ['34', '63', '5079'],
#  ['34', '66', '9883'],
#  ['34', '69', '2464'],
#  ['34', '74', '12774'],
#  ['34', '77', '848'],
#  ['34', '80', '10432'],
#  ['34', '83', '8043'],
#  ['34', '85', '7571'],
#  ['34', '98', '4740'],
#  ['35', '38', '6567'],
#  ['35', '39', '7346'],
#  ['35', '43', '6769'],
#  ['35', '53', '8334'],
#  ['35', '67', '7125'],
#  ['35', '77', '7161'],
#  ['35', '78', '920'],
#  ['35', '81', '1134'],
#  ['35', '82', '1220'],
#  ['35', '83', '10971'],
#  ['35', '86', '9645'],
#  ['35', '90', '1689'],
#  ['36', '37', '5448'],
#  ['36', '42', '7264'],
#  ['36', '45', '6822'],
#  ['36', '46', '9433'],
#  ['36', '55', '3351'],
#  ['36', '59', '2262'],
#  ['36', '61', '728'],
#  ['36', '67', '2735'],
#  ['36', '75', '5863'],
#  ['36', '79', '5674'],
#  ['36', '96', '4794'],
#  ['37', '40', '5384'],
#  ['37', '47', '4489'],
#  ['37', '51', '2790'],
#  ['37', '60', '3328'],
#  ['37', '63', '5260'],
#  ['37', '75', '5507'],
#  ['37', '78', '5820'],
#  ['37', '86', '4921'],
#  ['37', '95', '3639'],
#  ['38', '42', '9257'],
#  ['38', '46', '11702'],
#  ['38', '54', '8079'],
#  ['38', '55', '5547'],
#  ['38', '56', '8612'],
#  ['38', '62', '4843'],
#  ['38', '63', '3884'],
#  ['38', '70', '7633'],
#  ['38', '73', '1164'],
#  ['38', '88', '4388'],
#  ['38', '90', '4880'],
#  ['38', '91', '4203'],
#  ['38', '93', '6041'],
#  ['39', '40', '3493'],
#  ['39', '44', '4975'],
#  ['39', '47', '2480'],
#  ['39', '49', '3189'],
#  ['39', '58', '3136'],
#  ['39', '66', '8365'],
#  ['39', '68', '6155'],
#  ['39', '72', '3083'],
#  ['39', '75', '8202'],
#  ['39', '84', '8048'],
#  ['39', '87', '1939'],
#  ['39', '89', '2299'],
#  ['39', '98', '1250'],
#  ['40', '42', '7509'],
#  ['40', '46', '9446'],
#  ['40', '47', '1373'],
#  ['40', '48', '5371'],
#  ['40', '49', '3472'],
#  ['40', '50', '1734'],
#  ['40', '51', '8174'],
#  ['40', '59', '2248'],
#  ['40', '65', '6497'],
#  ['40', '67', '3182'],
#  ['40', '75', '5203'],
#  ['40', '76', '1708'],
#  ['40', '80', '6831'],
#  ['40', '95', '8072'],
#  ['40', '97', '6044'],
#  ['41', '48', '2580'],
#  ['41', '51', '6535'],
#  ['41', '54', '5359'],
#  ['41', '57', '2040'],
#  ['41', '59', '4536'],
#  ['41', '69', '3562'],
#  ['41', '76', '3304'],
#  ['41', '87', '1157'],
#  ['41', '88', '1615'],
#  ['41', '91', '454'],
#  ['41', '95', '5640'],
#  ['42', '43', '2952'],
#  ['42', '44', '1489'],
#  ['42', '52', '8226'],
#  ['42', '59', '9515'],
#  ['42', '63', '5653'],
#  ['42', '65', '4887'],
#  ['42', '70', '4077'],
#  ['42', '76', '7036'],
#  ['42', '81', '8533'],
#  ['42', '85', '5220'],
#  ['42', '88', '5532'],
#  ['43', '56', '5134'],
#  ['43', '59', '6573'],
#  ['43', '71', '3822'],
#  ['43', '76', '4501'],
#  ['43', '83', '4968'],
#  ['43', '90', '6076'],
#  ['43', '96', '6762'],
#  ['44', '46', '4129'],
#  ['44', '48', '2992'],
#  ['44', '50', '6943'],
#  ['44', '58', '1842'],
#  ['44', '64', '6956'],
#  ['44', '66', '6323'],
#  ['44', '69', '7086'],
#  ['44', '71', '5393'],
#  ['44', '72', '6994'],
#  ['44', '79', '675'],
#  ['44', '82', '6238'],
#  ['44', '86', '2665'],
#  ['44', '90', '7065'],
#  ['44', '91', '3751'],
#  ['44', '92', '2828'],
#  ['44', '93', '3276'],
#  ['44', '94', '4827'],
#  ['44', '95', '2045'],
#  ['45', '50', '7792'],
#  ['45', '61', '6102'],
#  ['45', '67', '8580'],
#  ['45', '70', '2877'],
#  ['45', '72', '7853'],
#  ['45', '80', '3543'],
#  ['45', '82', '7815'],
#  ['45', '86', '1289'],
#  ['45', '87', '3527'],
#  ['45', '91', '4426'],
#  ['45', '95', '1722'],
#  ['45', '96', '9033'],
#  ['46', '49', '6259'],
#  ['46', '51', '1416'],
#  ['46', '56', '5313'],
#  ['46', '67', '11861'],
#  ['46', '70', '7472'],
#  ['46', '74', '346'],
#  ['46', '76', '8412'],
#  ['46', '83', '9489'],
#  ['46', '84', '1350'],
#  ['46', '85', '8602'],
#  ['46', '87', '7146'],
#  ['46', '93', '5992'],
#  ['46', '99', '6850'],
#  ['47', '55', '3007'],
#  ['47', '63', '2302'],
#  ['47', '70', '5792'],
#  ['47', '72', '2315'],
#  ['47', '74', '8198'],
#  ['47', '79', '4641'],
#  ['47', '82', '3861'],
#  ['47', '85', '5266'],
#  ['47', '87', '2604'],
#  ['47', '95', '6819'],
#  ['47', '96', '4826'],
#  ['47', '97', '4936'],
#  ['48', '50', '5508'],
#  ['48', '54', '2937'],
#  ['48', '65', '1650'],
#  ['48', '67', '6050'],
#  ['48', '69', '5893'],
#  ['48', '79', '3475'],
#  ['48', '82', '7154'],
#  ['48', '84', '6245'],
#  ['48', '86', '2120'],
#  ['48', '90', '7367'],
#  ['48', '93', '4494'],
#  ['49', '55', '3365'],
#  ['49', '72', '4511'],
#  ['49', '76', '3222'],
#  ['49', '88', '1530'],
#  ['49', '95', '4603'],
#  ['50', '51', '9513'],
#  ['50', '58', '5336'],
#  ['50', '74', '10476'],
#  ['50', '78', '6670'],
#  ['50', '87', '4295'],
#  ['50', '92', '4591'],
#  ['50', '95', '8962'],
#  ['50', '98', '3617'],
#  ['51', '53', '9514'],
#  ['51', '55', '6311'],
#  ['51', '57', '6796'],
#  ['51', '59', '10409'],
#  ['51', '62', '6025'],
#  ['51', '64', '7507'],
#  ['51', '76', '7056'],
#  ['51', '88', '6197'],
#  ['51', '94', '8204'],
#  ['52', '58', '6560'],
#  ['52', '62', '5693'],
#  ['52', '68', '1765'],
#  ['52', '73', '5246'],
#  ['52', '76', '2323'],
#  ['52', '86', '9090'],
#  ['52', '88', '3876'],
#  ['52', '94', '9464'],
#  ['52', '97', '6228'],
#  ['53', '55', '6571'],
#  ['53', '61', '3229'],
#  ['53', '62', '3557'],
#  ['53', '64', '7808'],
#  ['53', '66', '9632'],
#  ['53', '67', '2892'],
#  ['53', '72', '3260'],
#  ['53', '74', '10264'],
#  ['53', '81', '9013'],
#  ['53', '82', '7405'],
#  ['53', '83', '3882'],
#  ['53', '88', '4484'],
#  ['53', '90', '6829'],
#  ['53', '94', '3371'],
#  ['54', '68', '10431'],
#  ['54', '72', '7753'],
#  ['54', '73', '8340'],
#  ['54', '80', '7503'],
#  ['54', '82', '10078'],
#  ['54', '83', '1236'],
#  ['54', '84', '8280'],
#  ['54', '85', '1527'],
#  ['54', '91', '4976'],
#  ['54', '92', '4084'],
#  ['55', '62', '4044'],
#  ['55', '67', '6007'],
#  ['55', '70', '7943'],
#  ['55', '72', '4547'],
#  ['55', '84', '6355'],
#  ['55', '97', '4837'],
#  ['56', '61', '6029'],
#  ['56', '62', '5536'],
#  ['56', '69', '7301'],
#  ['56', '76', '4304'],
#  ['56', '82', '3350'],
#  ['56', '99', '1636'],
#  ['57', '59', '3615'],
#  ['57', '62', '2414'],
#  ['57', '66', '5215'],
#  ['57', '68', '3045'],
#  ['57', '69', '2710'],
#  ['57', '72', '2883'],
#  ['57', '89', '4766'],
#  ['57', '92', '3397'],
#  ['58', '64', '6564'],
#  ['58', '68', '6602'],
#  ['58', '72', '5394'],
#  ['58', '75', '7544'],
#  ['58', '84', '5014'],
#  ['58', '87', '1199'],
#  ['58', '92', '986'],
#  ['59', '61', '2942'],
#  ['59', '68', '3830'],
#  ['59', '74', '11415'],
#  ['59', '81', '6578'],
#  ['59', '86', '8869'],
#  ['59', '88', '4222'],
#  ['59', '93', '5767'],
#  ['59', '96', '5482'],
#  ['60', '70', '9028'],
#  ['60', '72', '7013'],
#  ['60', '73', '6935'],
#  ['60', '75', '2394'],
#  ['60', '80', '4358'],
#  ['60', '82', '2346'],
#  ['60', '87', '6321'],
#  ['60', '94', '9290'],
#  ['60', '99', '554'],
#  ['61', '67', '3098'],
#  ['61', '70', '5855'],
#  ['61', '71', '2035'],
#  ['61', '73', '2237'],
#  ['61', '75', '6049'],
#  ['61', '83', '6136'],
#  ['61', '85', '5219'],
#  ['61', '95', '7166'],
#  ['61', '97', '5348'],
#  ['62', '73', '4433'],
#  ['62', '76', '3627'],
#  ['62', '84', '5931'],
#  ['62', '86', '3894'],
#  ['62', '89', '2475'],
#  ['62', '92', '990'],
#  ['62', '96', '6175'],
#  ['63', '66', '7985'],
#  ['63', '73', '3874'],
#  ['63', '74', '8409'],
#  ['63', '75', '7941'],
#  ['63', '77', '4235'],
#  ['63', '81', '7650'],
#  ['63', '85', '3047'],
#  ['63', '96', '7103'],
#  ['64', '65', '9274'],
#  ['64', '67', '6696'],
#  ['64', '69', '4786'],
#  ['64', '87', '6424'],
#  ['64', '89', '8103'],
#  ['64', '92', '6622'],
#  ['64', '98', '7972'],
#  ['65', '70', '1121'],
#  ['65', '72', '6309'],
#  ['65', '74', '8247'],
#  ['65', '77', '6899'],
#  ['65', '78', '10539'],
#  ['65', '79', '5012'],
#  ['65', '80', '6693'],
#  ['65', '81', '10139'],
#  ['65', '83', '1342'],
#  ['65', '87', '2857'],
#  ['65', '88', '5470'],
#  ['65', '89', '1172'],
#  ['65', '90', '8724'],
#  ['65', '97', '5530'],
#  ['65', '98', '3047'],
#  ['66', '69', '7473'],
#  ['66', '80', '4890'],
#  ['66', '83', '11260'],
#  ['66', '86', '8931'],
#  ['66', '87', '7243'],
#  ['66', '90', '4470'],
#  ['66', '92', '7321'],
#  ['66', '99', '1309'],
#  ['67', '68', '5467'],
#  ['67', '74', '11658'],
#  ['67', '77', '485'],
#  ['67', '80', '9343'],
#  ['67', '82', '6547'],
#  ['67', '85', '6257'],
#  ['67', '86', '8170'],
#  ['67', '87', '5061'],
#  ['67', '90', '5443'],
#  ['67', '92', '5339'],
#  ['67', '93', '6342'],
#  ['68', '73', '3734'],
#  ['68', '74', '9565'],
#  ['68', '87', '6199'],
#  ['68', '94', '9013'],
#  ['69', '76', '3060'],
#  ['69', '84', '9445'],
#  ['69', '95', '9125'],
#  ['70', '74', '7482'],
#  ['70', '77', '7882'],
#  ['70', '81', '10318'],
#  ['70', '82', '8931'],
#  ['70', '83', '2040'],
#  ['70', '86', '1628'],
#  ['70', '87', '3228'],
#  ['70', '89', '1816'],
#  ['70', '90', '9173'],
#  ['70', '91', '4044'],
#  ['70', '92', '2988'],
#  ['70', '95', '4570'],
#  ['70', '99', '8961'],
#  ['71', '72', '2583'],
#  ['71', '74', '9309'],
#  ['71', '76', '4452'],
#  ['71', '81', '7795'],
#  ['71', '85', '3643'],
#  ['72', '76', '3428'],
#  ['72', '84', '9501'],
#  ['72', '87', '4360'],
#  ['73', '78', '6323'],
#  ['73', '81', '6367'],
#  ['73', '87', '4849'],
#  ['74', '87', '7007'],
#  ['75', '76', '3626'],
#  ['75', '77', '8319'],
#  ['75', '81', '322'],
#  ['75', '86', '9983'],
#  ['75', '89', '9293'],
#  ['75', '92', '7760'],
#  ['76', '83', '8292'],
#  ['76', '85', '7280'],
#  ['76', '88', '1780'],
#  ['76', '98', '5799'],
#  ['77', '79', '8378'],
#  ['77', '80', '9717'],
#  ['77', '84', '11052'],
#  ['77', '85', '6739'],
#  ['77', '90', '5472'],
#  ['78', '91', '7156'],
#  ['78', '96', '984'],
#  ['79', '83', '6346'],
#  ['79', '92', '3105'],
#  ['79', '97', '521'],
#  ['79', '99', '5022'],
#  ['80', '84', '1337'],
#  ['80', '85', '6992'],
#  ['80', '89', '5953'],
#  ['80', '93', '3376'],
#  ['80', '97', '1197'],
#  ['81', '85', '10278'],
#  ['81', '92', '7446'],
#  ['81', '94', '10302'],
#  ['81', '98', '9128'],
#  ['82', '91', '5278'],
#  ['82', '95', '8004'],
#  ['82', '97', '5637'],
#  ['82', '99', '1792'],
#  ['83', '84', '8931'],
#  ['83', '88', '6617'],
#  ['83', '94', '1060'],
#  ['83', '97', '6862'],
#  ['83', '99', '10193'],
#  ['85', '91', '3565'],
#  ['85', '96', '9909'],
#  ['86', '89', '2663'],
#  ['86', '93', '5495'],
#  ['86', '99', '8146'],
#  ['88', '96', '4336'],
#  ['89', '94', '1332'],
#  ['89', '95', '5137'],
#  ['89', '97', '4760'],
#  ['90', '95', '8979'],
#  ['90', '98', '7062'],
#  ['92', '95', '4627'],
#  ['92', '97', '3597'],
#  ['93', '98', '5844'],
#  ['94', '98', '2791'],
#  ['95', '99', '7115']]

# %%
for elem in vertID_squareLoc_dict:
    current_vertex = elem 
    
    for item in temp_list:

        vertex_adj_dict[current_vertex] = []
        
        for i in temp_list:
            if i[0] == current_vertex:
                vertex_adj_dict[current_vertex].append((i[1],i[2]))
                
            if i[1] == current_vertex:
                vertex_adj_dict[current_vertex].append((i[0],i[2]))
    
            

            
vertex_adj_dict
# Out:
# {'0': [('2', '1218'),
#   ('9', '324'),
#   ('14', '6247'),
#   ('22', '4069'),
#   ('24', '1408'),
#   ('25', '10401'),
#   ('27', '6424'),
#   ('28', '4683'),
#   ('31', '1863'),
#   ('40', '1784'),
#   ('52', '4759'),
#   ('56', '7436'),
#   ('61', '2734'),
#   ('64', '4481'),
#   ('70', '8440'),
#   ('71', '3979'),
#   ('73', '863'),
#   ('76', '3133'),
#   ('82', '4494'),
#   ('91', '4528'),
#   ('94', '7572'),
#   ('99', '6157')],
#  '1': [('14', '2316'),
#   ('16', '5720'),
#   ('29', '7370'),
#   ('33', '9203'),
#   ('42', '7994'),
#   ('54', '10570'),
#   ('55', '1479'),
#   ('56', '3402'),
#   ('61', '4655'),
#   ('62', '5523'),
#   ('64', '476'),
#   ('69', '5036'),
#   ('74', '8152'),
#   ('85', '9284'),
#   ('88', '3721'),
#   ('94', '9303')],
#  '2': [('0', '1218'),
#   ('19', '2719'),
#   ('28', '4229'),
#   ('30', '2583'),
#   ('34', '2754'),
#   ('35', '5122'),
#   ('37', '6361'),
#   ('46', '10363'),
#   ('47', '1964'),
#   ('54', '7914'),
#   ('56', '7031'),
#   ('59', '1338'),
#   ('75', '6229'),
#   ('77', '2223'),
#   ('79', '6606'),
#   ('83', '7179'),
#   ('90', '3464'),
#   ('92', '4567'),
#   ('94', '6367'),
#   ('98', '4019')],
#  '3': [('15', '8713'),
#   ('37', '5748'),
#   ('46', '9509'),
#   ('49', '5563'),
#   ('53', '8121'),
#   ('54', '11199'),
#   ('61', '4932'),
#   ('66', '3617'),
#   ('70', '10100'),
#   ('73', '5076'),
#   ('76', '2581'),
#   ('88', '4291'),
#   ('89', '8585'),
#   ('91', '6292'),
#   ('99', '2767')],
#  '4': [('5', '2490'),
#   ('9', '6983'),
#   ('11', '1958'),
#   ('26', '3843'),
#   ('35', '7518'),
#   ('38', '7230'),
#   ('53', '5434'),
#   ('56', '5412'),
#   ('61', '4588'),
#   ('66', '6770'),
#   ('67', '7253'),
#   ('72', '6399'),
#   ('88', '3721'),
#   ('89', '2892'),
#   ('90', '6943'),
#   ('94', '3978'),
#   ('95', '2653'),
#   ('96', '7517')],
#  '5': [('4', '2490'),
#   ('27', '8471'),
#   ('29', '9663'),
#   ('38', '9662'),
#   ('43', '3452'),
#   ('49', '4638'),
#   ('55', '7527'),
#   ('67', '9640'),
#   ('74', '3908'),
#   ('81', '9360'),
#   ('83', '5792'),
#   ('84', '3687'),
#   ('85', '5029'),
#   ('86', '2126'),
#   ('87', '4580'),
#   ('89', '4545'),
#   ('96', '9606')],
#  '6': [('12', '2335'),
#   ('13', '6461'),
#   ('19', '5110'),
#   ('29', '6465'),
#   ('31', '3997'),
#   ('35', '1319'),
#   ('37', '4746'),
#   ('40', '2938'),
#   ('44', '6405'),
#   ('45', '7937'),
#   ('50', '4615'),
#   ('53', '7045'),
#   ('57', '2661'),
#   ('76', '1406'),
#   ('77', '6127'),
#   ('86', '8465'),
#   ('87', '5689'),
#   ('89', '7359'),
#   ('92', '5894')],
#  '7': [('16', '3660'),
#   ('17', '3769'),
#   ('20', '1541'),
#   ('21', '7256'),
#   ('22', '5327'),
#   ('25', '2678'),
#   ('27', '6512'),
#   ('28', '4826'),
#   ('29', '8650'),
#   ('33', '4541'),
#   ('34', '9747'),
#   ('37', '2237'),
#   ('42', '1146'),
#   ('51', '2850'),
#   ('56', '4788'),
#   ('65', '4969'),
#   ('66', '6266'),
#   ('68', '7700'),
#   ('78', '7997'),
#   ('80', '1810'),
#   ('89', '4353'),
#   ('93', '3563')],
#  '8': [('10', '6135'),
#   ('21', '4683'),
#   ('24', '2747'),
#   ('25', '7661'),
#   ('36', '948'),
#   ('42', '6446'),
#   ('55', '2688'),
#   ('58', '3656'),
#   ('62', '2306'),
#   ('66', '5877'),
#   ('68', '3356'),
#   ('77', '3933'),
#   ('80', '5904'),
#   ('87', '2962'),
#   ('88', '1078'),
#   ('93', '2719'),
#   ('94', '5660'),
#   ('98', '4028'),
#   ('99', '4577')],
#  '9': [('0', '324'),
#   ('4', '6983'),
#   ('18', '4669'),
#   ('20', '8257'),
#   ('44', '7470'),
#   ('45', '8513'),
#   ('46', '10961'),
#   ('48', '6456'),
#   ('53', '4441'),
#   ('54', '8810'),
#   ('57', '2895'),
#   ('59', '789'),
#   ('73', '643'),
#   ('80', '8347'),
#   ('86', '8456'),
#   ('95', '9516')],
#  '10': [('8', '6135'),
#   ('17', '3949'),
#   ('21', '1670'),
#   ('26', '5039'),
#   ('30', '8765'),
#   ('31', '7141'),
#   ('35', '2317'),
#   ('53', '10024'),
#   ('66', '1592'),
#   ('78', '1568'),
#   ('85', '11030')],
#  '11': [('4', '1958'),
#   ('14', '3312'),
#   ('22', '3982'),
#   ('38', '6676'),
#   ('45', '3402'),
#   ('48', '3506'),
#   ('50', '5667'),
#   ('51', '3876'),
#   ('52', '5060'),
#   ('54', '6323'),
#   ('60', '4020'),
#   ('62', '2263'),
#   ('80', '2480'),
#   ('83', '6486'),
#   ('91', '3006'),
#   ('94', '5439'),
#   ('96', '5634'),
#   ('97', '1568')],
#  '12': [('6', '2335'),
#   ('14', '2414'),
#   ('16', '4855'),
#   ('19', '3430'),
#   ('22', '3751'),
#   ('29', '5927'),
#   ('31', '3328'),
#   ('33', '6398'),
#   ('34', '6457'),
#   ('36', '2876'),
#   ('46', '6977'),
#   ('51', '5646'),
#   ('56', '3418'),
#   ('68', '3226'),
#   ('69', '4006'),
#   ('71', '4365'),
#   ('72', '4217'),
#   ('83', '7590'),
#   ('87', '3526'),
#   ('95', '6068'),
#   ('97', '3791'),
#   ('98', '5611')],
#  '13': [('6', '6461'),
#   ('25', '12228'),
#   ('26', '10111'),
#   ('30', '1159'),
#   ('32', '3342'),
#   ('36', '3699'),
#   ('39', '4803'),
#   ('42', '10640'),
#   ('46', '13081'),
#   ('49', '6834'),
#   ('51', '11900'),
#   ('56', '9814'),
#   ('59', '1839'),
#   ('60', '9144'),
#   ('66', '9915'),
#   ('76', '5540'),
#   ('81', '8413'),
#   ('83', '8167'),
#   ('96', '7303')],
#  '14': [('0', '6247'),
#   ('1', '2316'),
#   ('11', '3312'),
#   ('12', '2414'),
#   ('16', '3408'),
#   ('20', '6280'),
#   ('23', '5338'),
#   ('26', '2648'),
#   ('27', '1550'),
#   ('32', '6866'),
#   ('37', '2737'),
#   ('44', '4914'),
#   ('46', '6180'),
#   ('67', '7900'),
#   ('69', '6152'),
#   ('70', '8306'),
#   ('76', '3122'),
#   ('78', '3139'),
#   ('82', '2187'),
#   ('83', '9613'),
#   ('86', '7438')],
#  '15': [('3', '8713'),
#   ('16', '9060'),
#   ('18', '8262'),
#   ('23', '6123'),
#   ('26', '7865'),
#   ('29', '4060'),
#   ('31', '4150'),
#   ('41', '3108'),
#   ('43', '4072'),
#   ('50', '4332'),
#   ('51', '8800'),
#   ('52', '8446'),
#   ('62', '3227'),
#   ('63', '1755'),
#   ('68', '7696'),
#   ('75', '9693'),
#   ('77', '4755'),
#   ('85', '2003'),
#   ('87', '2654'),
#   ('89', '1831'),
#   ('92', '2729'),
#   ('93', '5850'),
#   ('95', '6945'),
#   ('96', '8832'),
#   ('98', '844')],
#  '16': [('1', '5720'),
#   ('7', '3660'),
#   ('12', '4855'),
#   ('14', '3408'),
#   ('15', '9060'),
#   ('32', '8847'),
#   ('38', '10035'),
#   ('42', '4400'),
#   ('44', '4050'),
#   ('48', '6899'),
#   ('57', '6143'),
#   ('60', '3544'),
#   ('65', '8462'),
#   ('68', '7304'),
#   ('78', '6348'),
#   ('80', '1852'),
#   ('82', '5584'),
#   ('89', '7642'),
#   ('98', '9304')],
#  '17': [('7', '3769'),
#   ('10', '3949'),
#   ('30', '7943'),
#   ('31', '5163'),
#   ('39', '5804'),
#   ('43', '3544'),
#   ('47', '3925'),
#   ('52', '3399'),
#   ('69', '5850'),
#   ('74', '5154'),
#   ('85', '7341'),
#   ('92', '4522'),
#   ('98', '7042')],
#  '18': [('9', '4669'),
#   ('15', '8262'),
#   ('39', '6758'),
#   ('42', '7993'),
#   ('44', '6636'),
#   ('48', '7605'),
#   ('56', '3454'),
#   ('57', '3365'),
#   ('58', '6331'),
#   ('60', '2375'),
#   ('62', '5479'),
#   ('63', '6515'),
#   ('67', '6860'),
#   ('73', '5176'),
#   ('75', '1462'),
#   ('77', '6948'),
#   ('82', '451'),
#   ('93', '3389'),
#   ('97', '5997')],
#  '19': [('2', '2719'),
#   ('6', '5110'),
#   ('12', '3430'),
#   ('21', '6570'),
#   ('28', '4242'),
#   ('30', '5042'),
#   ('34', '4679'),
#   ('63', '751'),
#   ('64', '5881'),
#   ('73', '3249'),
#   ('75', '7265'),
#   ('76', '3707'),
#   ('78', '7246'),
#   ('79', '4658'),
#   ('92', '1959')],
#  '20': [('7', '1541'),
#   ('9', '8257'),
#   ('14', '6280'),
#   ('22', '5046'),
#   ('26', '4433'),
#   ('31', '6796'),
#   ('35', '8732'),
#   ('36', '6567'),
#   ('38', '8402'),
#   ('39', '5147'),
#   ('44', '1369'),
#   ('53', '6289'),
#   ('54', '4246'),
#   ('55', '6596'),
#   ('73', '8062'),
#   ('75', '8939'),
#   ('77', '8835'),
#   ('78', '9182'),
#   ('82', '7519'),
#   ('87', '3315'),
#   ('95', '1752')],
#  '21': [('7', '7256'),
#   ('8', '4683'),
#   ('10', '1670'),
#   ('19', '6570'),
#   ('25', '8025'),
#   ('38', '7054'),
#   ('39', '7505'),
#   ('53', '8577'),
#   ('55', '2124'),
#   ('59', '6105'),
#   ('63', '7251'),
#   ('69', '5683'),
#   ('72', '6151'),
#   ('73', '5893'),
#   ('77', '7664'),
#   ('82', '1179'),
#   ('83', '10989'),
#   ('90', '2250'),
#   ('92', '7114'),
#   ('93', '3924'),
#   ('96', '815')],
#  '22': [('0', '4069'),
#   ('7', '5327'),
#   ('11', '3982'),
#   ('12', '3751'),
#   ('20', '5046'),
#   ('26', '6429'),
#   ('27', '7184'),
#   ('36', '2279'),
#   ('41', '1300'),
#   ('48', '2798'),
#   ('49', '2705'),
#   ('52', '6318'),
#   ('53', '1911'),
#   ('55', '4808'),
#   ('59', '4033'),
#   ('62', '1751'),
#   ('73', '3341'),
#   ('80', '6391'),
#   ('82', '5705'),
#   ('84', '7682'),
#   ('91', '993'),
#   ('93', '4034'),
#   ('95', '6612'),
#   ('97', '5277'),
#   ('98', '1860'),
#   ('99', '6515')],
#  '23': [('14', '5338'),
#   ('15', '6123'),
#   ('24', '553'),
#   ('46', '10556'),
#   ('60', '5742'),
#   ('62', '4699'),
#   ('64', '3512'),
#   ('75', '5060'),
#   ('95', '9348')],
#  '24': [('0', '1408'),
#   ('8', '2747'),
#   ('23', '553'),
#   ('27', '5144'),
#   ('28', '3771'),
#   ('36', '2361'),
#   ('37', '6523'),
#   ('40', '1734'),
#   ('42', '9025'),
#   ('44', '7535'),
#   ('50', '2626'),
#   ('51', '9273'),
#   ('53', '5699'),
#   ('56', '6379'),
#   ('64', '3121'),
#   ('66', '6180'),
#   ('67', '3824'),
#   ('71', '4756'),
#   ('72', '2567')],
#  '25': [('0', '10401'),
#   ('7', '2678'),
#   ('8', '7661'),
#   ('13', '12228'),
#   ('21', '8025'),
#   ('30', '12092'),
#   ('34', '12139'),
#   ('41', '6724'),
#   ('42', '2703'),
#   ('46', '859'),
#   ('56', '4796'),
#   ('58', '5121'),
#   ('59', '10821'),
#   ('71', '8612'),
#   ('74', '730'),
#   ('81', '8006'),
#   ('86', '5183'),
#   ('90', '8849')],
#  '26': [('4', '3843'),
#   ('10', '5039'),
#   ('13', '10111'),
#   ('14', '2648'),
#   ('15', '7865'),
#   ('20', '4433'),
#   ('22', '6429'),
#   ('31', '6841'),
#   ('33', '7117'),
#   ('46', '3562'),
#   ('51', '2148'),
#   ('58', '4326'),
#   ('63', '6416'),
#   ('66', '3531'),
#   ('67', '9064'),
#   ('71', '7152'),
#   ('73', '7923'),
#   ('78', '5770'),
#   ('79', '2488'),
#   ('85', '7687'),
#   ('89', '6526'),
#   ('95', '3988'),
#   ('97', '2030'),
#   ('98', '8074'),
#   ('99', '3357')],
#  '27': [('0', '6424'),
#   ('5', '8471'),
#   ('7', '6512'),
#   ('14', '1550'),
#   ('22', '7184'),
#   ('24', '5144'),
#   ('29', '8830'),
#   ('32', '7696'),
#   ('34', '8922'),
#   ('38', '7933'),
#   ('40', '5250'),
#   ('44', '6463'),
#   ('49', '5247'),
#   ('56', '2142'),
#   ('64', '2132'),
#   ('86', '8964'),
#   ('90', '3402'),
#   ('91', '6572'),
#   ('92', '7020')],
#  '28': [('0', '4683'),
#   ('2', '4229'),
#   ('7', '4826'),
#   ('19', '4242'),
#   ('24', '3771'),
#   ('33', '7153'),
#   ('48', '5592'),
#   ('63', '4835'),
#   ('64', '2394'),
#   ('65', '7162'),
#   ('66', '3228'),
#   ('71', '5163'),
#   ('74', '6645'),
#   ('80', '4389'),
#   ('81', '2985'),
#   ('90', '2662'),
#   ('91', '3939'),
#   ('92', '4466')],
#  '29': [('1', '7370'),
#   ('5', '9663'),
#   ('6', '6465'),
#   ('7', '8650'),
#   ('12', '5927'),
#   ('15', '4060'),
#   ('27', '8830'),
#   ('33', '6760'),
#   ('34', '1533'),
#   ('37', '8260'),
#   ('38', '1088'),
#   ('50', '1853'),
#   ('55', '6395'),
#   ('57', '4590'),
#   ('62', '5012'),
#   ('69', '2360'),
#   ('73', '2200'),
#   ('74', '11827'),
#   ('76', '5286'),
#   ('81', '8500'),
#   ('85', '6059'),
#   ('92', '5366'),
#   ('93', '6619')],
#  '30': [('2', '2583'),
#   ('10', '8765'),
#   ('13', '1159'),
#   ('17', '7943'),
#   ('19', '5042'),
#   ('25', '12092'),
#   ('45', '10192'),
#   ('47', '4547'),
#   ('61', '4170'),
#   ('66', '9212'),
#   ('67', '2162'),
#   ('76', '4962'),
#   ('80', '10326'),
#   ('84', '11657'),
#   ('90', '4847'),
#   ('91', '5771'),
#   ('92', '6988'),
#   ('98', '5568')],
#  '31': [('0', '1863'),
#   ('6', '3997'),
#   ('10', '7141'),
#   ('12', '3328'),
#   ('15', '4150'),
#   ('17', '5163'),
#   ('20', '6796'),
#   ('26', '6841'),
#   ('32', '1674'),
#   ('36', '457'),
#   ('40', '1065'),
#   ('42', '7543'),
#   ('44', '6107'),
#   ('47', '1383'),
#   ('73', '1268'),
#   ('79', '6009'),
#   ('85', '5795'),
#   ('87', '3610'),
#   ('94', '5775')],
#  '32': [('13', '3342'),
#   ('14', '6866'),
#   ('16', '8847'),
#   ('27', '7696'),
#   ('31', '1674'),
#   ('35', '6846'),
#   ('42', '7418'),
#   ('47', '2292'),
#   ('48', '4150'),
#   ('53', '1583'),
#   ('55', '5229'),
#   ('67', '1907'),
#   ('68', '5419'),
#   ('71', '935'),
#   ('73', '2333'),
#   ('85', '4541'),
#   ('86', '6269'),
#   ('88', '3365'),
#   ('90', '5292'),
#   ('92', '3445'),
#   ('99', '7126')],
#  '33': [('1', '9203'),
#   ('7', '4541'),
#   ('12', '6398'),
#   ('26', '7117'),
#   ('28', '7153'),
#   ('29', '6760'),
#   ('38', '7163'),
#   ('51', '7372'),
#   ('55', '7726'),
#   ('60', '8937'),
#   ('63', '3413'),
#   ('66', '9821'),
#   ('70', '505'),
#   ('71', '4173'),
#   ('72', '6712'),
#   ('73', '7281'),
#   ('75', '10455'),
#   ('76', '7327'),
#   ('82', '8713'),
#   ('84', '7194'),
#   ('86', '1991'),
#   ('92', '2724'),
#   ('94', '1034'),
#   ('96', '9878'),
#   ('97', '5172')],
#  '34': [('2', '2754'),
#   ('7', '9747'),
#   ('12', '6457'),
#   ('19', '4679'),
#   ('25', '12139'),
#   ('27', '8922'),
#   ('29', '1533'),
#   ('41', '5520'),
#   ('46', '12993'),
#   ('47', '4584'),
#   ('52', '7289'),
#   ('55', '6621'),
#   ('62', '6127'),
#   ('63', '5079'),
#   ('66', '9883'),
#   ('69', '2464'),
#   ('74', '12774'),
#   ('77', '848'),
#   ('80', '10432'),
#   ('83', '8043'),
#   ('85', '7571'),
#   ('98', '4740')],
#  '35': [('2', '5122'),
#   ('4', '7518'),
#   ('6', '1319'),
#   ('10', '2317'),
#   ('20', '8732'),
#   ('32', '6846'),
#   ('38', '6567'),
#   ('39', '7346'),
#   ('43', '6769'),
#   ('53', '8334'),
#   ('67', '7125'),
#   ('77', '7161'),
#   ('78', '920'),
#   ('81', '1134'),
#   ('82', '1220'),
#   ('83', '10971'),
#   ('86', '9645'),
#   ('90', '1689')],
#  '36': [('8', '948'),
#   ('12', '2876'),
#   ('13', '3699'),
#   ('20', '6567'),
#   ('22', '2279'),
#   ('24', '2361'),
#   ('31', '457'),
#   ('37', '5448'),
#   ('42', '7264'),
#   ('45', '6822'),
#   ('46', '9433'),
#   ('55', '3351'),
#   ('59', '2262'),
#   ('61', '728'),
#   ('67', '2735'),
#   ('75', '5863'),
#   ('79', '5674'),
#   ('96', '4794')],
#  '37': [('2', '6361'),
#   ('3', '5748'),
#   ('6', '4746'),
#   ('7', '2237'),
#   ('14', '2737'),
#   ('24', '6523'),
#   ('29', '8260'),
#   ('36', '5448'),
#   ('40', '5384'),
#   ('47', '4489'),
#   ('51', '2790'),
#   ('60', '3328'),
#   ('63', '5260'),
#   ('75', '5507'),
#   ('78', '5820'),
#   ('86', '4921'),
#   ('95', '3639')],
#  '38': [('4', '7230'),
#   ('5', '9662'),
#   ('11', '6676'),
#   ('16', '10035'),
#   ('20', '8402'),
#   ('21', '7054'),
#   ('27', '7933'),
#   ('29', '1088'),
#   ('33', '7163'),
#   ('35', '6567'),
#   ('42', '9257'),
#   ('46', '11702'),
#   ('54', '8079'),
#   ('55', '5547'),
#   ('56', '8612'),
#   ('62', '4843'),
#   ('63', '3884'),
#   ('70', '7633'),
#   ('73', '1164'),
#   ('88', '4388'),
#   ('90', '4880'),
#   ('91', '4203'),
#   ('93', '6041')],
#  '39': [('13', '4803'),
#   ('17', '5804'),
#   ('18', '6758'),
#   ('20', '5147'),
#   ('21', '7505'),
#   ('35', '7346'),
#   ('40', '3493'),
#   ('44', '4975'),
#   ('47', '2480'),
#   ('49', '3189'),
#   ('58', '3136'),
#   ('66', '8365'),
#   ('68', '6155'),
#   ('72', '3083'),
#   ('75', '8202'),
#   ('84', '8048'),
#   ('87', '1939'),
#   ('89', '2299'),
#   ('98', '1250')],
#  '40': [('0', '1784'),
#   ('6', '2938'),
#   ('24', '1734'),
#   ('27', '5250'),
#   ('31', '1065'),
#   ('37', '5384'),
#   ('39', '3493'),
#   ('42', '7509'),
#   ('46', '9446'),
#   ('47', '1373'),
#   ('48', '5371'),
#   ('49', '3472'),
#   ('50', '1734'),
#   ('51', '8174'),
#   ('59', '2248'),
#   ('65', '6497'),
#   ('67', '3182'),
#   ('75', '5203'),
#   ('76', '1708'),
#   ('80', '6831'),
#   ('95', '8072'),
#   ('97', '6044')],
#  '41': [('15', '3108'),
#   ('22', '1300'),
#   ('25', '6724'),
#   ('34', '5520'),
#   ('48', '2580'),
#   ('51', '6535'),
#   ('54', '5359'),
#   ('57', '2040'),
#   ('59', '4536'),
#   ('69', '3562'),
#   ('76', '3304'),
#   ('87', '1157'),
#   ('88', '1615'),
#   ('91', '454'),
#   ('95', '5640')],
#  '42': [('1', '7994'),
#   ('7', '1146'),
#   ('8', '6446'),
#   ('13', '10640'),
#   ('16', '4400'),
#   ('18', '7993'),
#   ('24', '9025'),
#   ('25', '2703'),
#   ('31', '7543'),
#   ('32', '7418'),
#   ('36', '7264'),
#   ('38', '9257'),
#   ('40', '7509'),
#   ('43', '2952'),
#   ('44', '1489'),
#   ('52', '8226'),
#   ('59', '9515'),
#   ('63', '5653'),
#   ('65', '4887'),
#   ('70', '4077'),
#   ('76', '7036'),
#   ('81', '8533'),
#   ('85', '5220'),
#   ('88', '5532')],
#  '43': [('5', '3452'),
#   ('15', '4072'),
#   ('17', '3544'),
#   ('35', '6769'),
#   ('42', '2952'),
#   ('56', '5134'),
#   ('59', '6573'),
#   ('71', '3822'),
#   ('76', '4501'),
#   ('83', '4968'),
#   ('90', '6076'),
#   ('96', '6762')],
#  '44': [('6', '6405'),
#   ('9', '7470'),
#   ('14', '4914'),
#   ('16', '4050'),
#   ('18', '6636'),
#   ('20', '1369'),
#   ('24', '7535'),
#   ('27', '6463'),
#   ('31', '6107'),
#   ('39', '4975'),
#   ('42', '1489'),
#   ('46', '4129'),
#   ('48', '2992'),
#   ('50', '6943'),
#   ('58', '1842'),
#   ('64', '6956'),
#   ('66', '6323'),
#   ('69', '7086'),
#   ('71', '5393'),
#   ('72', '6994'),
#   ('79', '675'),
#   ('82', '6238'),
#   ('86', '2665'),
#   ('90', '7065'),
#   ('91', '3751'),
#   ('92', '2828'),
#   ('93', '3276'),
#   ('94', '4827'),
#   ('95', '2045')],
#  '45': [('6', '7937'),
#   ('9', '8513'),
#   ('11', '3402'),
#   ('30', '10192'),
#   ('36', '6822'),
#   ('50', '7792'),
#   ('61', '6102'),
#   ('67', '8580'),
#   ('70', '2877'),
#   ('72', '7853'),
#   ('80', '3543'),
#   ('82', '7815'),
#   ('86', '1289'),
#   ('87', '3527'),
#   ('91', '4426'),
#   ('95', '1722'),
#   ('96', '9033')],
#  '46': [('2', '10363'),
#   ('3', '9509'),
#   ('9', '10961'),
#   ('12', '6977'),
#   ('13', '13081'),
#   ('14', '6180'),
#   ('23', '10556'),
#   ('25', '859'),
#   ('26', '3562'),
#   ('34', '12993'),
#   ('36', '9433'),
#   ('38', '11702'),
#   ('40', '9446'),
#   ('44', '4129'),
#   ('49', '6259'),
#   ('51', '1416'),
#   ('56', '5313'),
#   ('67', '11861'),
#   ('70', '7472'),
#   ('74', '346'),
#   ('76', '8412'),
#   ('83', '9489'),
#   ('84', '1350'),
#   ('85', '8602'),
#   ('87', '7146'),
#   ('93', '5992'),
#   ('99', '6850')],
#  '47': [('2', '1964'),
#   ('17', '3925'),
#   ('30', '4547'),
#   ('31', '1383'),
#   ('32', '2292'),
#   ('34', '4584'),
#   ('37', '4489'),
#   ('39', '2480'),
#   ('40', '1373'),
#   ('55', '3007'),
#   ('63', '2302'),
#   ('70', '5792'),
#   ('72', '2315'),
#   ('74', '8198'),
#   ('79', '4641'),
#   ('82', '3861'),
#   ('85', '5266'),
#   ('87', '2604'),
#   ('95', '6819'),
#   ('96', '4826'),
#   ('97', '4936')],
#  '48': [('9', '6456'),
#   ('11', '3506'),
#   ('16', '6899'),
#   ('18', '7605'),
#   ('22', '2798'),
#   ('28', '5592'),
#   ('32', '4150'),
#   ('40', '5371'),
#   ('41', '2580'),
#   ('44', '2992'),
#   ('50', '5508'),
#   ('54', '2937'),
#   ('65', '1650'),
#   ('67', '6050'),
#   ('69', '5893'),
#   ('79', '3475'),
#   ('82', '7154'),
#   ('84', '6245'),
#   ('86', '2120'),
#   ('90', '7367'),
#   ('93', '4494')],
#  '49': [('3', '5563'),
#   ('5', '4638'),
#   ('13', '6834'),
#   ('22', '2705'),
#   ('27', '5247'),
#   ('39', '3189'),
#   ('40', '3472'),
#   ('46', '6259'),
#   ('55', '3365'),
#   ('72', '4511'),
#   ('76', '3222'),
#   ('88', '1530'),
#   ('95', '4603')],
#  '50': [('6', '4615'),
#   ('11', '5667'),
#   ('15', '4332'),
#   ('24', '2626'),
#   ('29', '1853'),
#   ('40', '1734'),
#   ('44', '6943'),
#   ('45', '7792'),
#   ('48', '5508'),
#   ('51', '9513'),
#   ('58', '5336'),
#   ('74', '10476'),
#   ('78', '6670'),
#   ('87', '4295'),
#   ('92', '4591'),
#   ('95', '8962'),
#   ('98', '3617')],
#  '51': [('7', '2850'),
#   ('11', '3876'),
#   ('12', '5646'),
#   ('13', '11900'),
#   ('15', '8800'),
#   ('24', '9273'),
#   ('26', '2148'),
#   ('33', '7372'),
#   ('37', '2790'),
#   ('40', '8174'),
#   ('41', '6535'),
#   ('46', '1416'),
#   ('50', '9513'),
#   ('53', '9514'),
#   ('55', '6311'),
#   ('57', '6796'),
#   ('59', '10409'),
#   ('62', '6025'),
#   ('64', '7507'),
#   ('76', '7056'),
#   ('88', '6197'),
#   ('94', '8204')],
#  '52': [('0', '4759'),
#   ('11', '5060'),
#   ('15', '8446'),
#   ('17', '3399'),
#   ('22', '6318'),
#   ('34', '7289'),
#   ('42', '8226'),
#   ('58', '6560'),
#   ('62', '5693'),
#   ('68', '1765'),
#   ('73', '5246'),
#   ('76', '2323'),
#   ('86', '9090'),
#   ('88', '3876'),
#   ('94', '9464'),
#   ('97', '6228')],
#  '53': [('3', '8121'),
#   ('4', '5434'),
#   ('6', '7045'),
#   ('9', '4441'),
#   ('10', '10024'),
#   ('20', '6289'),
#   ('21', '8577'),
#   ('22', '1911'),
#   ('24', '5699'),
#   ('32', '1583'),
#   ('35', '8334'),
#   ('51', '9514'),
#   ('55', '6571'),
#   ('61', '3229'),
#   ('62', '3557'),
#   ('64', '7808'),
#   ('66', '9632'),
#   ('67', '2892'),
#   ('72', '3260'),
#   ('74', '10264'),
#   ('81', '9013'),
#   ('82', '7405'),
#   ('83', '3882'),
#   ('88', '4484'),
#   ('90', '6829'),
#   ('94', '3371')],
#  '54': [('1', '10570'),
#   ('2', '7914'),
#   ('3', '11199'),
#   ('9', '8810'),
#   ('11', '6323'),
#   ('20', '4246'),
#   ('38', '8079'),
#   ('41', '5359'),
#   ('48', '2937'),
#   ('68', '10431'),
#   ('72', '7753'),
#   ('73', '8340'),
#   ('80', '7503'),
#   ('82', '10078'),
#   ('83', '1236'),
#   ('84', '8280'),
#   ('85', '1527'),
#   ('91', '4976'),
#   ('92', '4084')],
#  '55': [('1', '1479'),
#   ('5', '7527'),
#   ('8', '2688'),
#   ('20', '6596'),
#   ('21', '2124'),
#   ('22', '4808'),
#   ('29', '6395'),
#   ('32', '5229'),
#   ('33', '7726'),
#   ('34', '6621'),
#   ('36', '3351'),
#   ('38', '5547'),
#   ('47', '3007'),
#   ('49', '3365'),
#   ('51', '6311'),
#   ('53', '6571'),
#   ('62', '4044'),
#   ('67', '6007'),
#   ('70', '7943'),
#   ('72', '4547'),
#   ('84', '6355'),
#   ('97', '4837')],
#  '56': [('0', '7436'),
#   ('1', '3402'),
#   ('2', '7031'),
#   ('4', '5412'),
#   ('7', '4788'),
#   ('12', '3418'),
#   ('13', '9814'),
#   ('18', '3454'),
#   ('24', '6379'),
#   ('25', '4796'),
#   ('27', '2142'),
#   ('38', '8612'),
#   ('43', '5134'),
#   ('46', '5313'),
#   ('61', '6029'),
#   ('62', '5536'),
#   ('69', '7301'),
#   ('76', '4304'),
#   ('82', '3350'),
#   ('99', '1636')],
#  '57': [('6', '2661'),
#   ('9', '2895'),
#   ('16', '6143'),
#   ('18', '3365'),
#   ('29', '4590'),
#   ('41', '2040'),
#   ('51', '6796'),
#   ('59', '3615'),
#   ('62', '2414'),
#   ('66', '5215'),
#   ('68', '3045'),
#   ('69', '2710'),
#   ('72', '2883'),
#   ('89', '4766'),
#   ('92', '3397')],
#  '58': [('8', '3656'),
#   ('18', '6331'),
#   ('25', '5121'),
#   ('26', '4326'),
#   ('39', '3136'),
#   ('44', '1842'),
#   ('50', '5336'),
#   ('52', '6560'),
#   ('64', '6564'),
#   ('68', '6602'),
#   ('72', '5394'),
#   ('75', '7544'),
#   ('84', '5014'),
#   ('87', '1199'),
#   ('92', '986')],
#  '59': [('2', '1338'),
#   ('9', '789'),
#   ('13', '1839'),
#   ('21', '6105'),
#   ('22', '4033'),
#   ('25', '10821'),
#   ('36', '2262'),
#   ('40', '2248'),
#   ('41', '4536'),
#   ('42', '9515'),
#   ('43', '6573'),
#   ('51', '10409'),
#   ('57', '3615'),
#   ('61', '2942'),
#   ('68', '3830'),
#   ('74', '11415'),
#   ('81', '6578'),
#   ('86', '8869'),
#   ('88', '4222'),
#   ('93', '5767'),
#   ('96', '5482')],
#  '60': [('11', '4020'),
#   ('13', '9144'),
#   ('16', '3544'),
#   ('18', '2375'),
#   ('23', '5742'),
#   ('33', '8937'),
#   ('37', '3328'),
#   ('70', '9028'),
#   ('72', '7013'),
#   ('73', '6935'),
#   ('75', '2394'),
#   ('80', '4358'),
#   ('82', '2346'),
#   ('87', '6321'),
#   ('94', '9290'),
#   ('99', '554')],
#  '61': [('0', '2734'),
#   ('1', '4655'),
#   ('3', '4932'),
#   ('4', '4588'),
#   ('30', '4170'),
#   ('36', '728'),
#   ('45', '6102'),
#   ('53', '3229'),
#   ('56', '6029'),
#   ('59', '2942'),
#   ('67', '3098'),
#   ('70', '5855'),
#   ('71', '2035'),
#   ('73', '2237'),
#   ('75', '6049'),
#   ('83', '6136'),
#   ('85', '5219'),
#   ('95', '7166'),
#   ('97', '5348')],
#  '62': [('1', '5523'),
#   ('8', '2306'),
#   ('11', '2263'),
#   ('15', '3227'),
#   ('18', '5479'),
#   ('22', '1751'),
#   ('23', '4699'),
#   ('29', '5012'),
#   ('34', '6127'),
#   ('38', '4843'),
#   ('51', '6025'),
#   ('52', '5693'),
#   ('53', '3557'),
#   ('55', '4044'),
#   ('56', '5536'),
#   ('57', '2414'),
#   ('73', '4433'),
#   ('76', '3627'),
#   ('84', '5931'),
#   ('86', '3894'),
#   ('89', '2475'),
#   ('92', '990'),
#   ('96', '6175')],
#  '63': [('15', '1755'),
#   ('18', '6515'),
#   ('19', '751'),
#   ('21', '7251'),
#   ('26', '6416'),
#   ('28', '4835'),
#   ('33', '3413'),
#   ('34', '5079'),
#   ('37', '5260'),
#   ('38', '3884'),
#   ('42', '5653'),
#   ('47', '2302'),
#   ('66', '7985'),
#   ('73', '3874'),
#   ('74', '8409'),
#   ('75', '7941'),
#   ('77', '4235'),
#   ('81', '7650'),
#   ('85', '3047'),
#   ('96', '7103')],
#  '64': [('0', '4481'),
#   ('1', '476'),
#   ('19', '5881'),
#   ('23', '3512'),
#   ('24', '3121'),
#   ('27', '2132'),
#   ('28', '2394'),
#   ('44', '6956'),
#   ('51', '7507'),
#   ('53', '7808'),
#   ('58', '6564'),
#   ('65', '9274'),
#   ('67', '6696'),
#   ('69', '4786'),
#   ('87', '6424'),
#   ('89', '8103'),
#   ('92', '6622'),
#   ('98', '7972')],
#  '65': [('7', '4969'),
#   ('16', '8462'),
#   ('28', '7162'),
#   ('40', '6497'),
#   ('42', '4887'),
#   ('48', '1650'),
#   ('64', '9274'),
#   ('70', '1121'),
#   ('72', '6309'),
#   ('74', '8247'),
#   ('77', '6899'),
#   ('78', '10539'),
#   ('79', '5012'),
#   ('80', '6693'),
#   ('81', '10139'),
#   ('83', '1342'),
#   ('87', '2857'),
#   ('88', '5470'),
#   ('89', '1172'),
#   ('90', '8724'),
#   ('97', '5530'),
#   ('98', '3047')],
#  '66': [('3', '3617'),
#   ('4', '6770'),
#   ('7', '6266'),
#   ('8', '5877'),
#   ('10', '1592'),
#   ('13', '9915'),
#   ('24', '6180'),
#   ('26', '3531'),
#   ('28', '3228'),
#   ('30', '9212'),
#   ('33', '9821'),
#   ('34', '9883'),
#   ('39', '8365'),
#   ('44', '6323'),
#   ('53', '9632'),
#   ('57', '5215'),
#   ('63', '7985'),
#   ('69', '7473'),
#   ('80', '4890'),
#   ('83', '11260'),
#   ('86', '8931'),
#   ('87', '7243'),
#   ('90', '4470'),
#   ('92', '7321'),
#   ('99', '1309')],
#  '67': [('4', '7253'),
#   ('5', '9640'),
#   ('14', '7900'),
#   ('18', '6860'),
#   ('24', '3824'),
#   ('26', '9064'),
#   ('30', '2162'),
#   ('32', '1907'),
#   ('35', '7125'),
#   ('36', '2735'),
#   ('40', '3182'),
#   ('45', '8580'),
#   ('46', '11861'),
#   ('48', '6050'),
#   ('53', '2892'),
#   ('55', '6007'),
#   ('61', '3098'),
#   ('64', '6696'),
#   ('68', '5467'),
#   ('74', '11658'),
#   ('77', '485'),
#   ('80', '9343'),
#   ('82', '6547'),
#   ('85', '6257'),
#   ('86', '8170'),
#   ('87', '5061'),
#   ('90', '5443'),
#   ('92', '5339'),
#   ('93', '6342')],
#  '68': [('7', '7700'),
#   ('8', '3356'),
#   ('12', '3226'),
#   ('15', '7696'),
#   ('16', '7304'),
#   ('32', '5419'),
#   ('39', '6155'),
#   ('52', '1765'),
#   ('54', '10431'),
#   ('57', '3045'),
#   ('58', '6602'),
#   ('59', '3830'),
#   ('67', '5467'),
#   ('73', '3734'),
#   ('74', '9565'),
#   ('87', '6199'),
#   ('94', '9013')],
#  '69': [('1', '5036'),
#   ('12', '4006'),
#   ('14', '6152'),
#   ('17', '5850'),
#   ('21', '5683'),
#   ('29', '2360'),
#   ('34', '2464'),
#   ('41', '3562'),
#   ('44', '7086'),
#   ('48', '5893'),
#   ('56', '7301'),
#   ('57', '2710'),
#   ('64', '4786'),
#   ('66', '7473'),
#   ('76', '3060'),
#   ('84', '9445'),
#   ('95', '9125')],
#  '70': [('0', '8440'),
#   ('3', '10100'),
#   ('14', '8306'),
#   ('33', '505'),
#   ('38', '7633'),
#   ('42', '4077'),
#   ('45', '2877'),
#   ('46', '7472'),
#   ('47', '5792'),
#   ('55', '7943'),
#   ('60', '9028'),
#   ('61', '5855'),
#   ('65', '1121'),
#   ('74', '7482'),
#   ('77', '7882'),
#   ('81', '10318'),
#   ('82', '8931'),
#   ('83', '2040'),
#   ('86', '1628'),
#   ('87', '3228'),
#   ('89', '1816'),
#   ('90', '9173'),
#   ('91', '4044'),
#   ('92', '2988'),
#   ('95', '4570'),
#   ('99', '8961')],
#  '71': [('0', '3979'),
#   ('12', '4365'),
#   ('24', '4756'),
#   ('25', '8612'),
#   ('26', '7152'),
#   ('28', '5163'),
#   ('32', '935'),
#   ('33', '4173'),
#   ('43', '3822'),
#   ('44', '5393'),
#   ('61', '2035'),
#   ('72', '2583'),
#   ('74', '9309'),
#   ('76', '4452'),
#   ('81', '7795'),
#   ('85', '3643')],
#  '72': [('4', '6399'),
#   ('12', '4217'),
#   ('21', '6151'),
#   ('24', '2567'),
#   ('33', '6712'),
#   ('39', '3083'),
#   ('44', '6994'),
#   ('45', '7853'),
#   ('47', '2315'),
#   ('49', '4511'),
#   ('53', '3260'),
#   ('54', '7753'),
#   ('55', '4547'),
#   ('57', '2883'),
#   ('58', '5394'),
#   ('60', '7013'),
#   ('65', '6309'),
#   ('71', '2583'),
#   ('76', '3428'),
#   ('84', '9501'),
#   ('87', '4360')],
#  '73': [('0', '863'),
#   ('3', '5076'),
#   ('9', '643'),
#   ('18', '5176'),
#   ('19', '3249'),
#   ('20', '8062'),
#   ('21', '5893'),
#   ('22', '3341'),
#   ('26', '7923'),
#   ('29', '2200'),
#   ('31', '1268'),
#   ('32', '2333'),
#   ('33', '7281'),
#   ('38', '1164'),
#   ('52', '5246'),
#   ('54', '8340'),
#   ('60', '6935'),
#   ('61', '2237'),
#   ('62', '4433'),
#   ('63', '3874'),
#   ('68', '3734'),
#   ('78', '6323'),
#   ('81', '6367'),
#   ('87', '4849')],
#  '74': [('1', '8152'),
#   ('5', '3908'),
#   ('17', '5154'),
#   ('25', '730'),
#   ('28', '6645'),
#   ('29', '11827'),
#   ('34', '12774'),
#   ('46', '346'),
#   ('47', '8198'),
#   ('50', '10476'),
#   ('53', '10264'),
#   ('59', '11415'),
#   ('63', '8409'),
#   ('65', '8247'),
#   ('67', '11658'),
#   ('68', '9565'),
#   ('70', '7482'),
#   ('71', '9309'),
#   ('87', '7007')],
#  '75': [('2', '6229'),
#   ('15', '9693'),
#   ('18', '1462'),
#   ('19', '7265'),
#   ('20', '8939'),
#   ('23', '5060'),
#   ('33', '10455'),
#   ('36', '5863'),
#   ('37', '5507'),
#   ('39', '8202'),
#   ('40', '5203'),
#   ('58', '7544'),
#   ('60', '2394'),
#   ('61', '6049'),
#   ('63', '7941'),
#   ('76', '3626'),
#   ('77', '8319'),
#   ('81', '322'),
#   ('86', '9983'),
#   ('89', '9293'),
#   ('92', '7760')],
#  '76': [('0', '3133'),
#   ('3', '2581'),
#   ('6', '1406'),
#   ('13', '5540'),
#   ('14', '3122'),
#   ('19', '3707'),
#   ('29', '5286'),
#   ('30', '4962'),
#   ('33', '7327'),
#   ('40', '1708'),
#   ('41', '3304'),
#   ('42', '7036'),
#   ('43', '4501'),
#   ('46', '8412'),
#   ('49', '3222'),
#   ('51', '7056'),
#   ('52', '2323'),
#   ('56', '4304'),
#   ('62', '3627'),
#   ('69', '3060'),
#   ('71', '4452'),
#   ('72', '3428'),
#   ('75', '3626'),
#   ('83', '8292'),
#   ('85', '7280'),
#   ('88', '1780'),
#   ('98', '5799')],
#  '77': [('2', '2223'),
#   ('6', '6127'),
#   ('8', '3933'),
#   ('15', '4755'),
#   ('18', '6948'),
#   ('20', '8835'),
#   ('21', '7664'),
#   ('34', '848'),
#   ('35', '7161'),
#   ('63', '4235'),
#   ('65', '6899'),
#   ('67', '485'),
#   ('70', '7882'),
#   ('75', '8319'),
#   ('79', '8378'),
#   ('80', '9717'),
#   ('84', '11052'),
#   ('85', '6739'),
#   ('90', '5472')],
#  '78': [('7', '7997'),
#   ('10', '1568'),
#   ('14', '3139'),
#   ('16', '6348'),
#   ('19', '7246'),
#   ('20', '9182'),
#   ('26', '5770'),
#   ('35', '920'),
#   ('37', '5820'),
#   ('50', '6670'),
#   ('65', '10539'),
#   ('73', '6323'),
#   ('91', '7156'),
#   ('96', '984')],
#  '79': [('2', '6606'),
#   ('19', '4658'),
#   ('26', '2488'),
#   ('31', '6009'),
#   ('36', '5674'),
#   ('44', '675'),
#   ('47', '4641'),
#   ('48', '3475'),
#   ('65', '5012'),
#   ('77', '8378'),
#   ('83', '6346'),
#   ('92', '3105'),
#   ('97', '521'),
#   ('99', '5022')],
#  '80': [('7', '1810'),
#   ('8', '5904'),
#   ('9', '8347'),
#   ('11', '2480'),
#   ('16', '1852'),
#   ('22', '6391'),
#   ('28', '4389'),
#   ('30', '10326'),
#   ('34', '10432'),
#   ('40', '6831'),
#   ('45', '3543'),
#   ('54', '7503'),
#   ('60', '4358'),
#   ('65', '6693'),
#   ('66', '4890'),
#   ('67', '9343'),
#   ('77', '9717'),
#   ('84', '1337'),
#   ('85', '6992'),
#   ('89', '5953'),
#   ('93', '3376'),
#   ('97', '1197')],
#  '81': [('5', '9360'),
#   ('13', '8413'),
#   ('25', '8006'),
#   ('28', '2985'),
#   ('29', '8500'),
#   ('35', '1134'),
#   ('42', '8533'),
#   ('53', '9013'),
#   ('59', '6578'),
#   ('63', '7650'),
#   ('65', '10139'),
#   ('70', '10318'),
#   ('71', '7795'),
#   ('73', '6367'),
#   ('75', '322'),
#   ('85', '10278'),
#   ('92', '7446'),
#   ('94', '10302'),
#   ('98', '9128')],
#  '82': [('0', '4494'),
#   ('14', '2187'),
#   ('16', '5584'),
#   ('18', '451'),
#   ('20', '7519'),
#   ('21', '1179'),
#   ('22', '5705'),
#   ('33', '8713'),
#   ('35', '1220'),
#   ('44', '6238'),
#   ('45', '7815'),
#   ('47', '3861'),
#   ('48', '7154'),
#   ('53', '7405'),
#   ('54', '10078'),
#   ('56', '3350'),
#   ('60', '2346'),
#   ('67', '6547'),
#   ('70', '8931'),
#   ('91', '5278'),
#   ('95', '8004'),
#   ('97', '5637'),
#   ('99', '1792')],
#  '83': [('2', '7179'),
#   ('5', '5792'),
#   ('11', '6486'),
#   ('12', '7590'),
#   ('13', '8167'),
#   ('14', '9613'),
#   ('21', '10989'),
#   ('34', '8043'),
#   ('35', '10971'),
#   ('43', '4968'),
#   ('46', '9489'),
#   ('53', '3882'),
#   ('54', '1236'),
#   ('61', '6136'),
#   ('65', '1342'),
#   ('66', '11260'),
#   ('70', '2040'),
#   ('76', '8292'),
#   ('79', '6346'),
#   ('84', '8931'),
#   ('88', '6617'),
#   ('94', '1060'),
#   ('97', '6862'),
#   ('99', '10193')],
#  '84': [('5', '3687'),
#   ('22', '7682'),
#   ('30', '11657'),
#   ('33', '7194'),
#   ('39', '8048'),
#   ('46', '1350'),
#   ('48', '6245'),
#   ('54', '8280'),
#   ('55', '6355'),
#   ('58', '5014'),
#   ('62', '5931'),
#   ('69', '9445'),
#   ('72', '9501'),
#   ('77', '11052'),
#   ('80', '1337'),
#   ('83', '8931')],
#  '85': [('1', '9284'),
#   ('5', '5029'),
#   ('10', '11030'),
#   ('15', '2003'),
#   ('17', '7341'),
#   ('26', '7687'),
#   ('29', '6059'),
#   ('31', '5795'),
#   ('32', '4541'),
#   ('34', '7571'),
#   ('42', '5220'),
#   ('46', '8602'),
#   ('47', '5266'),
#   ('54', '1527'),
#   ('61', '5219'),
#   ('63', '3047'),
#   ('67', '6257'),
#   ('71', '3643'),
#   ('76', '7280'),
#   ('77', '6739'),
#   ('80', '6992'),
#   ('81', '10278'),
#   ('91', '3565'),
#   ('96', '9909')],
#  '86': [('5', '2126'),
#   ('6', '8465'),
#   ('9', '8456'),
#   ('14', '7438'),
#   ('25', '5183'),
#   ('27', '8964'),
#   ('32', '6269'),
#   ('33', '1991'),
#   ('35', '9645'),
#   ('37', '4921'),
#   ('44', '2665'),
#   ('45', '1289'),
#   ('48', '2120'),
#   ('52', '9090'),
#   ('59', '8869'),
#   ('62', '3894'),
#   ('66', '8931'),
#   ('67', '8170'),
#   ('70', '1628'),
#   ('75', '9983'),
#   ('89', '2663'),
#   ('93', '5495'),
#   ('99', '8146')],
#  '87': [('5', '4580'),
#   ('6', '5689'),
#   ('8', '2962'),
#   ('12', '3526'),
#   ('15', '2654'),
#   ('20', '3315'),
#   ('31', '3610'),
#   ('39', '1939'),
#   ('41', '1157'),
#   ('45', '3527'),
#   ('46', '7146'),
#   ('47', '2604'),
#   ('50', '4295'),
#   ('58', '1199'),
#   ('60', '6321'),
#   ('64', '6424'),
#   ('65', '2857'),
#   ('66', '7243'),
#   ('67', '5061'),
#   ('68', '6199'),
#   ('70', '3228'),
#   ('72', '4360'),
#   ('73', '4849'),
#   ('74', '7007')],
#  '88': [('1', '3721'),
#   ('3', '4291'),
#   ('4', '3721'),
#   ('8', '1078'),
#   ('32', '3365'),
#   ('38', '4388'),
#   ('41', '1615'),
#   ('42', '5532'),
#   ('49', '1530'),
#   ('51', '6197'),
#   ('52', '3876'),
#   ('53', '4484'),
#   ('59', '4222'),
#   ('65', '5470'),
#   ('76', '1780'),
#   ('83', '6617'),
#   ('96', '4336')],
#  '89': [('3', '8585'),
#   ('4', '2892'),
#   ('5', '4545'),
#   ('6', '7359'),
#   ('7', '4353'),
#   ('15', '1831'),
#   ('16', '7642'),
#   ('26', '6526'),
#   ('39', '2299'),
#   ('57', '4766'),
#   ('62', '2475'),
#   ('64', '8103'),
#   ('65', '1172'),
#   ('70', '1816'),
#   ('75', '9293'),
#   ('80', '5953'),
#   ('86', '2663'),
#   ('94', '1332'),
#   ('95', '5137'),
#   ('97', '4760')],
#  '90': [('2', '3464'),
#   ('4', '6943'),
#   ('21', '2250'),
#   ('25', '8849'),
#   ('27', '3402'),
#   ('28', '2662'),
#   ('30', '4847'),
#   ('32', '5292'),
#   ('35', '1689'),
#   ('38', '4880'),
#   ('43', '6076'),
#   ('44', '7065'),
#   ('48', '7367'),
#   ('53', '6829'),
#   ('65', '8724'),
#   ('66', '4470'),
#   ('67', '5443'),
#   ('70', '9173'),
#   ('77', '5472'),
#   ('95', '8979'),
#   ('98', '7062')],
#  '91': [('0', '4528'),
#   ('3', '6292'),
#   ('11', '3006'),
#   ('22', '993'),
#   ('27', '6572'),
#   ('28', '3939'),
#   ('30', '5771'),
#   ('38', '4203'),
#   ('41', '454'),
#   ('44', '3751'),
#   ('45', '4426'),
#   ('54', '4976'),
#   ('70', '4044'),
#   ('78', '7156'),
#   ('82', '5278'),
#   ('85', '3565')],
#  '92': [('2', '4567'),
#   ('6', '5894'),
#   ('15', '2729'),
#   ('17', '4522'),
#   ('19', '1959'),
#   ('21', '7114'),
#   ('27', '7020'),
#   ('28', '4466'),
#   ('29', '5366'),
#   ('30', '6988'),
#   ('32', '3445'),
#   ('33', '2724'),
#   ('44', '2828'),
#   ('50', '4591'),
#   ('54', '4084'),
#   ('57', '3397'),
#   ('58', '986'),
#   ('62', '990'),
#   ('64', '6622'),
#   ('66', '7321'),
#   ('67', '5339'),
#   ('70', '2988'),
#   ('75', '7760'),
#   ('79', '3105'),
#   ('81', '7446'),
#   ('95', '4627'),
#   ('97', '3597')],
#  '93': [('7', '3563'),
#   ('8', '2719'),
#   ('15', '5850'),
#   ('18', '3389'),
#   ('21', '3924'),
#   ('22', '4034'),
#   ('29', '6619'),
#   ('38', '6041'),
#   ('44', '3276'),
#   ('46', '5992'),
#   ('48', '4494'),
#   ('59', '5767'),
#   ('67', '6342'),
#   ('80', '3376'),
#   ('86', '5495'),
#   ('98', '5844')],
#  '94': [('0', '7572'),
#   ('1', '9303'),
#   ('2', '6367'),
#   ('4', '3978'),
#   ('8', '5660'),
#   ('11', '5439'),
#   ('31', '5775'),
#   ('33', '1034'),
#   ('44', '4827'),
#   ('51', '8204'),
#   ('52', '9464'),
#   ('53', '3371'),
#   ('60', '9290'),
#   ('68', '9013'),
#   ('81', '10302'),
#   ('83', '1060'),
#   ('89', '1332'),
#   ('98', '2791')],
#  '95': [('4', '2653'),
#   ('9', '9516'),
#   ('12', '6068'),
#   ('15', '6945'),
#   ('20', '1752'),
#   ('22', '6612'),
#   ('23', '9348'),
#   ('26', '3988'),
#   ('37', '3639'),
#   ('40', '8072'),
#   ('41', '5640'),
#   ('44', '2045'),
#   ('45', '1722'),
#   ('47', '6819'),
#   ('49', '4603'),
#   ('50', '8962'),
#   ('61', '7166'),
#   ('69', '9125'),
#   ('70', '4570'),
#   ('82', '8004'),
#   ('89', '5137'),
#   ('90', '8979'),
#   ('92', '4627'),
#   ('99', '7115')],
#  '96': [('4', '7517'),
#   ('5', '9606'),
#   ('11', '5634'),
#   ('13', '7303'),
#   ('15', '8832'),
#   ('21', '815'),
#   ('33', '9878'),
#   ('36', '4794'),
#   ('43', '6762'),
#   ('45', '9033'),
#   ('47', '4826'),
#   ('59', '5482'),
#   ('62', '6175'),
#   ('63', '7103'),
#   ('78', '984'),
#   ('85', '9909'),
#   ('88', '4336')],
#  '97': [('11', '1568'),
#   ('12', '3791'),
#   ('18', '5997'),
#   ('22', '5277'),
#   ('26', '2030'),
#   ('33', '5172'),
#   ('40', '6044'),
#   ('47', '4936'),
#   ('52', '6228'),
#   ('55', '4837'),
#   ('61', '5348'),
#   ('65', '5530'),
#   ('79', '521'),
#   ('80', '1197'),
#   ('82', '5637'),
#   ('83', '6862'),
#   ('89', '4760'),
#   ('92', '3597')],
#  '98': [('2', '4019'),
#   ('8', '4028'),
#   ('12', '5611'),
#   ('15', '844'),
#   ('16', '9304'),
#   ('17', '7042'),
#   ('22', '1860'),
#   ('26', '8074'),
#   ('30', '5568'),
#   ('34', '4740'),
#   ('39', '1250'),
#   ('50', '3617'),
#   ('64', '7972'),
#   ('65', '3047'),
#   ('76', '5799'),
#   ('81', '9128'),
#   ('90', '7062'),
#   ('93', '5844'),
#   ('94', '2791')],
#  '99': [('0', '6157'),
#   ('3', '2767'),
#   ('8', '4577'),
#   ('22', '6515'),
#   ('26', '3357'),
#   ('32', '7126'),
#   ('46', '6850'),
#   ('56', '1636'),
#   ('60', '554'),
#   ('66', '1309'),
#   ('70', '8961'),
#   ('79', '5022'),
#   ('82', '1792'),
#   ('83', '10193'),
#   ('86', '8146'),
#   ('95', '7115')]}

# %%
    
#for each entry in the list, find all the ones for a sin
#vertex and add them to a single key, and each value is a list
#of tuples, with the vertex and the distance to it
for item in temp_list:
    current_vertex = item[0]
    vertex_adj_dict[current_vertex] = []
    for i in temp_list:
        if i[0] == current_vertex:
            vertex_adj_dict[current_vertex].append((i[1],i[2]))

            

            
vertex_adj_dict
# Out:
# {'0': [('2', '1218'),
#   ('9', '324'),
#   ('14', '6247'),
#   ('22', '4069'),
#   ('24', '1408'),
#   ('25', '10401'),
#   ('27', '6424'),
#   ('28', '4683'),
#   ('31', '1863'),
#   ('40', '1784'),
#   ('52', '4759'),
#   ('56', '7436'),
#   ('61', '2734'),
#   ('64', '4481'),
#   ('70', '8440'),
#   ('71', '3979'),
#   ('73', '863'),
#   ('76', '3133'),
#   ('82', '4494'),
#   ('91', '4528'),
#   ('94', '7572'),
#   ('99', '6157')],
#  '2': [('19', '2719'),
#   ('28', '4229'),
#   ('30', '2583'),
#   ('34', '2754'),
#   ('35', '5122'),
#   ('37', '6361'),
#   ('46', '10363'),
#   ('47', '1964'),
#   ('54', '7914'),
#   ('56', '7031'),
#   ('59', '1338'),
#   ('75', '6229'),
#   ('77', '2223'),
#   ('79', '6606'),
#   ('83', '7179'),
#   ('90', '3464'),
#   ('92', '4567'),
#   ('94', '6367'),
#   ('98', '4019')],
#  '9': [('18', '4669'),
#   ('20', '8257'),
#   ('44', '7470'),
#   ('45', '8513'),
#   ('46', '10961'),
#   ('48', '6456'),
#   ('53', '4441'),
#   ('54', '8810'),
#   ('57', '2895'),
#   ('59', '789'),
#   ('73', '643'),
#   ('80', '8347'),
#   ('86', '8456'),
#   ('95', '9516')],
#  '14': [('16', '3408'),
#   ('20', '6280'),
#   ('23', '5338'),
#   ('26', '2648'),
#   ('27', '1550'),
#   ('32', '6866'),
#   ('37', '2737'),
#   ('44', '4914'),
#   ('46', '6180'),
#   ('67', '7900'),
#   ('69', '6152'),
#   ('70', '8306'),
#   ('76', '3122'),
#   ('78', '3139'),
#   ('82', '2187'),
#   ('83', '9613'),
#   ('86', '7438')],
#  '22': [('26', '6429'),
#   ('27', '7184'),
#   ('36', '2279'),
#   ('41', '1300'),
#   ('48', '2798'),
#   ('49', '2705'),
#   ('52', '6318'),
#   ('53', '1911'),
#   ('55', '4808'),
#   ('59', '4033'),
#   ('62', '1751'),
#   ('73', '3341'),
#   ('80', '6391'),
#   ('82', '5705'),
#   ('84', '7682'),
#   ('91', '993'),
#   ('93', '4034'),
#   ('95', '6612'),
#   ('97', '5277'),
#   ('98', '1860'),
#   ('99', '6515')],
#  '24': [('27', '5144'),
#   ('28', '3771'),
#   ('36', '2361'),
#   ('37', '6523'),
#   ('40', '1734'),
#   ('42', '9025'),
#   ('44', '7535'),
#   ('50', '2626'),
#   ('51', '9273'),
#   ('53', '5699'),
#   ('56', '6379'),
#   ('64', '3121'),
#   ('66', '6180'),
#   ('67', '3824'),
#   ('71', '4756'),
#   ('72', '2567')],
#  '25': [('30', '12092'),
#   ('34', '12139'),
#   ('41', '6724'),
#   ('42', '2703'),
#   ('46', '859'),
#   ('56', '4796'),
#   ('58', '5121'),
#   ('59', '10821'),
#   ('71', '8612'),
#   ('74', '730'),
#   ('81', '8006'),
#   ('86', '5183'),
#   ('90', '8849')],
#  '27': [('29', '8830'),
#   ('32', '7696'),
#   ('34', '8922'),
#   ('38', '7933'),
#   ('40', '5250'),
#   ('44', '6463'),
#   ('49', '5247'),
#   ('56', '2142'),
#   ('64', '2132'),
#   ('86', '8964'),
#   ('90', '3402'),
#   ('91', '6572'),
#   ('92', '7020')],
#  '28': [('33', '7153'),
#   ('48', '5592'),
#   ('63', '4835'),
#   ('64', '2394'),
#   ('65', '7162'),
#   ('66', '3228'),
#   ('71', '5163'),
#   ('74', '6645'),
#   ('80', '4389'),
#   ('81', '2985'),
#   ('90', '2662'),
#   ('91', '3939'),
#   ('92', '4466')],
#  '31': [('32', '1674'),
#   ('36', '457'),
#   ('40', '1065'),
#   ('42', '7543'),
#   ('44', '6107'),
#   ('47', '1383'),
#   ('73', '1268'),
#   ('79', '6009'),
#   ('85', '5795'),
#   ('87', '3610'),
#   ('94', '5775')],
#  '40': [('42', '7509'),
#   ('46', '9446'),
#   ('47', '1373'),
#   ('48', '5371'),
#   ('49', '3472'),
#   ('50', '1734'),
#   ('51', '8174'),
#   ('59', '2248'),
#   ('65', '6497'),
#   ('67', '3182'),
#   ('75', '5203'),
#   ('76', '1708'),
#   ('80', '6831'),
#   ('95', '8072'),
#   ('97', '6044')],
#  '52': [('58', '6560'),
#   ('62', '5693'),
#   ('68', '1765'),
#   ('73', '5246'),
#   ('76', '2323'),
#   ('86', '9090'),
#   ('88', '3876'),
#   ('94', '9464'),
#   ('97', '6228')],
#  '56': [('61', '6029'),
#   ('62', '5536'),
#   ('69', '7301'),
#   ('76', '4304'),
#   ('82', '3350'),
#   ('99', '1636')],
#  '61': [('67', '3098'),
#   ('70', '5855'),
#   ('71', '2035'),
#   ('73', '2237'),
#   ('75', '6049'),
#   ('83', '6136'),
#   ('85', '5219'),
#   ('95', '7166'),
#   ('97', '5348')],
#  '64': [('65', '9274'),
#   ('67', '6696'),
#   ('69', '4786'),
#   ('87', '6424'),
#   ('89', '8103'),
#   ('92', '6622'),
#   ('98', '7972')],
#  '70': [('74', '7482'),
#   ('77', '7882'),
#   ('81', '10318'),
#   ('82', '8931'),
#   ('83', '2040'),
#   ('86', '1628'),
#   ('87', '3228'),
#   ('89', '1816'),
#   ('90', '9173'),
#   ('91', '4044'),
#   ('92', '2988'),
#   ('95', '4570'),
#   ('99', '8961')],
#  '71': [('72', '2583'),
#   ('74', '9309'),
#   ('76', '4452'),
#   ('81', '7795'),
#   ('85', '3643')],
#  '73': [('78', '6323'), ('81', '6367'), ('87', '4849')],
#  '76': [('83', '8292'), ('85', '7280'), ('88', '1780'), ('98', '5799')],
#  '82': [('91', '5278'), ('95', '8004'), ('97', '5637'), ('99', '1792')],
#  '91': [],
#  '94': [('98', '2791')],
#  '99': [],
#  '1': [('14', '2316'),
#   ('16', '5720'),
#   ('29', '7370'),
#   ('33', '9203'),
#   ('42', '7994'),
#   ('54', '10570'),
#   ('55', '1479'),
#   ('56', '3402'),
#   ('61', '4655'),
#   ('62', '5523'),
#   ('64', '476'),
#   ('69', '5036'),
#   ('74', '8152'),
#   ('85', '9284'),
#   ('88', '3721'),
#   ('94', '9303')],
#  '16': [('32', '8847'),
#   ('38', '10035'),
#   ('42', '4400'),
#   ('44', '4050'),
#   ('48', '6899'),
#   ('57', '6143'),
#   ('60', '3544'),
#   ('65', '8462'),
#   ('68', '7304'),
#   ('78', '6348'),
#   ('80', '1852'),
#   ('82', '5584'),
#   ('89', '7642'),
#   ('98', '9304')],
#  '29': [('33', '6760'),
#   ('34', '1533'),
#   ('37', '8260'),
#   ('38', '1088'),
#   ('50', '1853'),
#   ('55', '6395'),
#   ('57', '4590'),
#   ('62', '5012'),
#   ('69', '2360'),
#   ('73', '2200'),
#   ('74', '11827'),
#   ('76', '5286'),
#   ('81', '8500'),
#   ('85', '6059'),
#   ('92', '5366'),
#   ('93', '6619')],
#  '33': [('38', '7163'),
#   ('51', '7372'),
#   ('55', '7726'),
#   ('60', '8937'),
#   ('63', '3413'),
#   ('66', '9821'),
#   ('70', '505'),
#   ('71', '4173'),
#   ('72', '6712'),
#   ('73', '7281'),
#   ('75', '10455'),
#   ('76', '7327'),
#   ('82', '8713'),
#   ('84', '7194'),
#   ('86', '1991'),
#   ('92', '2724'),
#   ('94', '1034'),
#   ('96', '9878'),
#   ('97', '5172')],
#  '42': [('43', '2952'),
#   ('44', '1489'),
#   ('52', '8226'),
#   ('59', '9515'),
#   ('63', '5653'),
#   ('65', '4887'),
#   ('70', '4077'),
#   ('76', '7036'),
#   ('81', '8533'),
#   ('85', '5220'),
#   ('88', '5532')],
#  '54': [('68', '10431'),
#   ('72', '7753'),
#   ('73', '8340'),
#   ('80', '7503'),
#   ('82', '10078'),
#   ('83', '1236'),
#   ('84', '8280'),
#   ('85', '1527'),
#   ('91', '4976'),
#   ('92', '4084')],
#  '55': [('62', '4044'),
#   ('67', '6007'),
#   ('70', '7943'),
#   ('72', '4547'),
#   ('84', '6355'),
#   ('97', '4837')],
#  '62': [('73', '4433'),
#   ('76', '3627'),
#   ('84', '5931'),
#   ('86', '3894'),
#   ('89', '2475'),
#   ('92', '990'),
#   ('96', '6175')],
#  '69': [('76', '3060'), ('84', '9445'), ('95', '9125')],
#  '74': [('87', '7007')],
#  '85': [('91', '3565'), ('96', '9909')],
#  '88': [('96', '4336')],
#  '19': [('21', '6570'),
#   ('28', '4242'),
#   ('30', '5042'),
#   ('34', '4679'),
#   ('63', '751'),
#   ('64', '5881'),
#   ('73', '3249'),
#   ('75', '7265'),
#   ('76', '3707'),
#   ('78', '7246'),
#   ('79', '4658'),
#   ('92', '1959')],
#  '30': [('45', '10192'),
#   ('47', '4547'),
#   ('61', '4170'),
#   ('66', '9212'),
#   ('67', '2162'),
#   ('76', '4962'),
#   ('80', '10326'),
#   ('84', '11657'),
#   ('90', '4847'),
#   ('91', '5771'),
#   ('92', '6988'),
#   ('98', '5568')],
#  '34': [('41', '5520'),
#   ('46', '12993'),
#   ('47', '4584'),
#   ('52', '7289'),
#   ('55', '6621'),
#   ('62', '6127'),
#   ('63', '5079'),
#   ('66', '9883'),
#   ('69', '2464'),
#   ('74', '12774'),
#   ('77', '848'),
#   ('80', '10432'),
#   ('83', '8043'),
#   ('85', '7571'),
#   ('98', '4740')],
#  '35': [('38', '6567'),
#   ('39', '7346'),
#   ('43', '6769'),
#   ('53', '8334'),
#   ('67', '7125'),
#   ('77', '7161'),
#   ('78', '920'),
#   ('81', '1134'),
#   ('82', '1220'),
#   ('83', '10971'),
#   ('86', '9645'),
#   ('90', '1689')],
#  '37': [('40', '5384'),
#   ('47', '4489'),
#   ('51', '2790'),
#   ('60', '3328'),
#   ('63', '5260'),
#   ('75', '5507'),
#   ('78', '5820'),
#   ('86', '4921'),
#   ('95', '3639')],
#  '46': [('49', '6259'),
#   ('51', '1416'),
#   ('56', '5313'),
#   ('67', '11861'),
#   ('70', '7472'),
#   ('74', '346'),
#   ('76', '8412'),
#   ('83', '9489'),
#   ('84', '1350'),
#   ('85', '8602'),
#   ('87', '7146'),
#   ('93', '5992'),
#   ('99', '6850')],
#  '47': [('55', '3007'),
#   ('63', '2302'),
#   ('70', '5792'),
#   ('72', '2315'),
#   ('74', '8198'),
#   ('79', '4641'),
#   ('82', '3861'),
#   ('85', '5266'),
#   ('87', '2604'),
#   ('95', '6819'),
#   ('96', '4826'),
#   ('97', '4936')],
#  '59': [('61', '2942'),
#   ('68', '3830'),
#   ('74', '11415'),
#   ('81', '6578'),
#   ('86', '8869'),
#   ('88', '4222'),
#   ('93', '5767'),
#   ('96', '5482')],
#  '75': [('76', '3626'),
#   ('77', '8319'),
#   ('81', '322'),
#   ('86', '9983'),
#   ('89', '9293'),
#   ('92', '7760')],
#  '77': [('79', '8378'),
#   ('80', '9717'),
#   ('84', '11052'),
#   ('85', '6739'),
#   ('90', '5472')],
#  '79': [('83', '6346'), ('92', '3105'), ('97', '521'), ('99', '5022')],
#  '83': [('84', '8931'),
#   ('88', '6617'),
#   ('94', '1060'),
#   ('97', '6862'),
#   ('99', '10193')],
#  '90': [('95', '8979'), ('98', '7062')],
#  '92': [('95', '4627'), ('97', '3597')],
#  '98': [],
#  '3': [('15', '8713'),
#   ('37', '5748'),
#   ('46', '9509'),
#   ('49', '5563'),
#   ('53', '8121'),
#   ('54', '11199'),
#   ('61', '4932'),
#   ('66', '3617'),
#   ('70', '10100'),
#   ('73', '5076'),
#   ('76', '2581'),
#   ('88', '4291'),
#   ('89', '8585'),
#   ('91', '6292'),
#   ('99', '2767')],
#  '15': [('16', '9060'),
#   ('18', '8262'),
#   ('23', '6123'),
#   ('26', '7865'),
#   ('29', '4060'),
#   ('31', '4150'),
#   ('41', '3108'),
#   ('43', '4072'),
#   ('50', '4332'),
#   ('51', '8800'),
#   ('52', '8446'),
#   ('62', '3227'),
#   ('63', '1755'),
#   ('68', '7696'),
#   ('75', '9693'),
#   ('77', '4755'),
#   ('85', '2003'),
#   ('87', '2654'),
#   ('89', '1831'),
#   ('92', '2729'),
#   ('93', '5850'),
#   ('95', '6945'),
#   ('96', '8832'),
#   ('98', '844')],
#  '49': [('55', '3365'),
#   ('72', '4511'),
#   ('76', '3222'),
#   ('88', '1530'),
#   ('95', '4603')],
#  '53': [('55', '6571'),
#   ('61', '3229'),
#   ('62', '3557'),
#   ('64', '7808'),
#   ('66', '9632'),
#   ('67', '2892'),
#   ('72', '3260'),
#   ('74', '10264'),
#   ('81', '9013'),
#   ('82', '7405'),
#   ('83', '3882'),
#   ('88', '4484'),
#   ('90', '6829'),
#   ('94', '3371')],
#  '66': [('69', '7473'),
#   ('80', '4890'),
#   ('83', '11260'),
#   ('86', '8931'),
#   ('87', '7243'),
#   ('90', '4470'),
#   ('92', '7321'),
#   ('99', '1309')],
#  '89': [('94', '1332'), ('95', '5137'), ('97', '4760')],
#  '4': [('5', '2490'),
#   ('9', '6983'),
#   ('11', '1958'),
#   ('26', '3843'),
#   ('35', '7518'),
#   ('38', '7230'),
#   ('53', '5434'),
#   ('56', '5412'),
#   ('61', '4588'),
#   ('66', '6770'),
#   ('67', '7253'),
#   ('72', '6399'),
#   ('88', '3721'),
#   ('89', '2892'),
#   ('90', '6943'),
#   ('94', '3978'),
#   ('95', '2653'),
#   ('96', '7517')],
#  '5': [('27', '8471'),
#   ('29', '9663'),
#   ('38', '9662'),
#   ('43', '3452'),
#   ('49', '4638'),
#   ('55', '7527'),
#   ('67', '9640'),
#   ('74', '3908'),
#   ('81', '9360'),
#   ('83', '5792'),
#   ('84', '3687'),
#   ('85', '5029'),
#   ('86', '2126'),
#   ('87', '4580'),
#   ('89', '4545'),
#   ('96', '9606')],
#  '11': [('14', '3312'),
#   ('22', '3982'),
#   ('38', '6676'),
#   ('45', '3402'),
#   ('48', '3506'),
#   ('50', '5667'),
#   ('51', '3876'),
#   ('52', '5060'),
#   ('54', '6323'),
#   ('60', '4020'),
#   ('62', '2263'),
#   ('80', '2480'),
#   ('83', '6486'),
#   ('91', '3006'),
#   ('94', '5439'),
#   ('96', '5634'),
#   ('97', '1568')],
#  '26': [('31', '6841'),
#   ('33', '7117'),
#   ('46', '3562'),
#   ('51', '2148'),
#   ('58', '4326'),
#   ('63', '6416'),
#   ('66', '3531'),
#   ('67', '9064'),
#   ('71', '7152'),
#   ('73', '7923'),
#   ('78', '5770'),
#   ('79', '2488'),
#   ('85', '7687'),
#   ('89', '6526'),
#   ('95', '3988'),
#   ('97', '2030'),
#   ('98', '8074'),
#   ('99', '3357')],
#  '38': [('42', '9257'),
#   ('46', '11702'),
#   ('54', '8079'),
#   ('55', '5547'),
#   ('56', '8612'),
#   ('62', '4843'),
#   ('63', '3884'),
#   ('70', '7633'),
#   ('73', '1164'),
#   ('88', '4388'),
#   ('90', '4880'),
#   ('91', '4203'),
#   ('93', '6041')],
#  '67': [('68', '5467'),
#   ('74', '11658'),
#   ('77', '485'),
#   ('80', '9343'),
#   ('82', '6547'),
#   ('85', '6257'),
#   ('86', '8170'),
#   ('87', '5061'),
#   ('90', '5443'),
#   ('92', '5339'),
#   ('93', '6342')],
#  '72': [('76', '3428'), ('84', '9501'), ('87', '4360')],
#  '95': [('99', '7115')],
#  '96': [],
#  '43': [('56', '5134'),
#   ('59', '6573'),
#   ('71', '3822'),
#   ('76', '4501'),
#   ('83', '4968'),
#   ('90', '6076'),
#   ('96', '6762')],
#  '81': [('85', '10278'), ('92', '7446'), ('94', '10302'), ('98', '9128')],
#  '84': [],
#  '86': [('89', '2663'), ('93', '5495'), ('99', '8146')],
#  '87': [],
#  '6': [('12', '2335'),
#   ('13', '6461'),
#   ('19', '5110'),
#   ('29', '6465'),
#   ('31', '3997'),
#   ('35', '1319'),
#   ('37', '4746'),
#   ('40', '2938'),
#   ('44', '6405'),
#   ('45', '7937'),
#   ('50', '4615'),
#   ('53', '7045'),
#   ('57', '2661'),
#   ('76', '1406'),
#   ('77', '6127'),
#   ('86', '8465'),
#   ('87', '5689'),
#   ('89', '7359'),
#   ('92', '5894')],
#  '12': [('14', '2414'),
#   ('16', '4855'),
#   ('19', '3430'),
#   ('22', '3751'),
#   ('29', '5927'),
#   ('31', '3328'),
#   ('33', '6398'),
#   ('34', '6457'),
#   ('36', '2876'),
#   ('46', '6977'),
#   ('51', '5646'),
#   ('56', '3418'),
#   ('68', '3226'),
#   ('69', '4006'),
#   ('71', '4365'),
#   ('72', '4217'),
#   ('83', '7590'),
#   ('87', '3526'),
#   ('95', '6068'),
#   ('97', '3791'),
#   ('98', '5611')],
#  '13': [('25', '12228'),
#   ('26', '10111'),
#   ('30', '1159'),
#   ('32', '3342'),
#   ('36', '3699'),
#   ('39', '4803'),
#   ('42', '10640'),
#   ('46', '13081'),
#   ('49', '6834'),
#   ('51', '11900'),
#   ('56', '9814'),
#   ('59', '1839'),
#   ('60', '9144'),
#   ('66', '9915'),
#   ('76', '5540'),
#   ('81', '8413'),
#   ('83', '8167'),
#   ('96', '7303')],
#  '44': [('46', '4129'),
#   ('48', '2992'),
#   ('50', '6943'),
#   ('58', '1842'),
#   ('64', '6956'),
#   ('66', '6323'),
#   ('69', '7086'),
#   ('71', '5393'),
#   ('72', '6994'),
#   ('79', '675'),
#   ('82', '6238'),
#   ('86', '2665'),
#   ('90', '7065'),
#   ('91', '3751'),
#   ('92', '2828'),
#   ('93', '3276'),
#   ('94', '4827'),
#   ('95', '2045')],
#  '45': [('50', '7792'),
#   ('61', '6102'),
#   ('67', '8580'),
#   ('70', '2877'),
#   ('72', '7853'),
#   ('80', '3543'),
#   ('82', '7815'),
#   ('86', '1289'),
#   ('87', '3527'),
#   ('91', '4426'),
#   ('95', '1722'),
#   ('96', '9033')],
#  '50': [('51', '9513'),
#   ('58', '5336'),
#   ('74', '10476'),
#   ('78', '6670'),
#   ('87', '4295'),
#   ('92', '4591'),
#   ('95', '8962'),
#   ('98', '3617')],
#  '57': [('59', '3615'),
#   ('62', '2414'),
#   ('66', '5215'),
#   ('68', '3045'),
#   ('69', '2710'),
#   ('72', '2883'),
#   ('89', '4766'),
#   ('92', '3397')],
#  '7': [('16', '3660'),
#   ('17', '3769'),
#   ('20', '1541'),
#   ('21', '7256'),
#   ('22', '5327'),
#   ('25', '2678'),
#   ('27', '6512'),
#   ('28', '4826'),
#   ('29', '8650'),
#   ('33', '4541'),
#   ('34', '9747'),
#   ('37', '2237'),
#   ('42', '1146'),
#   ('51', '2850'),
#   ('56', '4788'),
#   ('65', '4969'),
#   ('66', '6266'),
#   ('68', '7700'),
#   ('78', '7997'),
#   ('80', '1810'),
#   ('89', '4353'),
#   ('93', '3563')],
#  '17': [('30', '7943'),
#   ('31', '5163'),
#   ('39', '5804'),
#   ('43', '3544'),
#   ('47', '3925'),
#   ('52', '3399'),
#   ('69', '5850'),
#   ('74', '5154'),
#   ('85', '7341'),
#   ('92', '4522'),
#   ('98', '7042')],
#  '20': [('22', '5046'),
#   ('26', '4433'),
#   ('31', '6796'),
#   ('35', '8732'),
#   ('36', '6567'),
#   ('38', '8402'),
#   ('39', '5147'),
#   ('44', '1369'),
#   ('53', '6289'),
#   ('54', '4246'),
#   ('55', '6596'),
#   ('73', '8062'),
#   ('75', '8939'),
#   ('77', '8835'),
#   ('78', '9182'),
#   ('82', '7519'),
#   ('87', '3315'),
#   ('95', '1752')],
#  '21': [('25', '8025'),
#   ('38', '7054'),
#   ('39', '7505'),
#   ('53', '8577'),
#   ('55', '2124'),
#   ('59', '6105'),
#   ('63', '7251'),
#   ('69', '5683'),
#   ('72', '6151'),
#   ('73', '5893'),
#   ('77', '7664'),
#   ('82', '1179'),
#   ('83', '10989'),
#   ('90', '2250'),
#   ('92', '7114'),
#   ('93', '3924'),
#   ('96', '815')],
#  '51': [('53', '9514'),
#   ('55', '6311'),
#   ('57', '6796'),
#   ('59', '10409'),
#   ('62', '6025'),
#   ('64', '7507'),
#   ('76', '7056'),
#   ('88', '6197'),
#   ('94', '8204')],
#  '65': [('70', '1121'),
#   ('72', '6309'),
#   ('74', '8247'),
#   ('77', '6899'),
#   ('78', '10539'),
#   ('79', '5012'),
#   ('80', '6693'),
#   ('81', '10139'),
#   ('83', '1342'),
#   ('87', '2857'),
#   ('88', '5470'),
#   ('89', '1172'),
#   ('90', '8724'),
#   ('97', '5530'),
#   ('98', '3047')],
#  '68': [('73', '3734'), ('74', '9565'), ('87', '6199'), ('94', '9013')],
#  '78': [('91', '7156'), ('96', '984')],
#  '80': [('84', '1337'),
#   ('85', '6992'),
#   ('89', '5953'),
#   ('93', '3376'),
#   ('97', '1197')],
#  '93': [('98', '5844')],
#  '8': [('10', '6135'),
#   ('21', '4683'),
#   ('24', '2747'),
#   ('25', '7661'),
#   ('36', '948'),
#   ('42', '6446'),
#   ('55', '2688'),
#   ('58', '3656'),
#   ('62', '2306'),
#   ('66', '5877'),
#   ('68', '3356'),
#   ('77', '3933'),
#   ('80', '5904'),
#   ('87', '2962'),
#   ('88', '1078'),
#   ('93', '2719'),
#   ('94', '5660'),
#   ('98', '4028'),
#   ('99', '4577')],
#  '10': [('17', '3949'),
#   ('21', '1670'),
#   ('26', '5039'),
#   ('30', '8765'),
#   ('31', '7141'),
#   ('35', '2317'),
#   ('53', '10024'),
#   ('66', '1592'),
#   ('78', '1568'),
#   ('85', '11030')],
#  '36': [('37', '5448'),
#   ('42', '7264'),
#   ('45', '6822'),
#   ('46', '9433'),
#   ('55', '3351'),
#   ('59', '2262'),
#   ('61', '728'),
#   ('67', '2735'),
#   ('75', '5863'),
#   ('79', '5674'),
#   ('96', '4794')],
#  '58': [('64', '6564'),
#   ('68', '6602'),
#   ('72', '5394'),
#   ('75', '7544'),
#   ('84', '5014'),
#   ('87', '1199'),
#   ('92', '986')],
#  '18': [('39', '6758'),
#   ('42', '7993'),
#   ('44', '6636'),
#   ('48', '7605'),
#   ('56', '3454'),
#   ('57', '3365'),
#   ('58', '6331'),
#   ('60', '2375'),
#   ('62', '5479'),
#   ('63', '6515'),
#   ('67', '6860'),
#   ('73', '5176'),
#   ('75', '1462'),
#   ('77', '6948'),
#   ('82', '451'),
#   ('93', '3389'),
#   ('97', '5997')],
#  '48': [('50', '5508'),
#   ('54', '2937'),
#   ('65', '1650'),
#   ('67', '6050'),
#   ('69', '5893'),
#   ('79', '3475'),
#   ('82', '7154'),
#   ('84', '6245'),
#   ('86', '2120'),
#   ('90', '7367'),
#   ('93', '4494')],
#  '60': [('70', '9028'),
#   ('72', '7013'),
#   ('73', '6935'),
#   ('75', '2394'),
#   ('80', '4358'),
#   ('82', '2346'),
#   ('87', '6321'),
#   ('94', '9290'),
#   ('99', '554')],
#  '97': [],
#  '32': [('35', '6846'),
#   ('42', '7418'),
#   ('47', '2292'),
#   ('48', '4150'),
#   ('53', '1583'),
#   ('55', '5229'),
#   ('67', '1907'),
#   ('68', '5419'),
#   ('71', '935'),
#   ('73', '2333'),
#   ('85', '4541'),
#   ('86', '6269'),
#   ('88', '3365'),
#   ('90', '5292'),
#   ('92', '3445'),
#   ('99', '7126')],
#  '39': [('40', '3493'),
#   ('44', '4975'),
#   ('47', '2480'),
#   ('49', '3189'),
#   ('58', '3136'),
#   ('66', '8365'),
#   ('68', '6155'),
#   ('72', '3083'),
#   ('75', '8202'),
#   ('84', '8048'),
#   ('87', '1939'),
#   ('89', '2299'),
#   ('98', '1250')],
#  '23': [('24', '553'),
#   ('46', '10556'),
#   ('60', '5742'),
#   ('62', '4699'),
#   ('64', '3512'),
#   ('75', '5060'),
#   ('95', '9348')],
#  '41': [('48', '2580'),
#   ('51', '6535'),
#   ('54', '5359'),
#   ('57', '2040'),
#   ('59', '4536'),
#   ('69', '3562'),
#   ('76', '3304'),
#   ('87', '1157'),
#   ('88', '1615'),
#   ('91', '454'),
#   ('95', '5640')],
#  '63': [('66', '7985'),
#   ('73', '3874'),
#   ('74', '8409'),
#   ('75', '7941'),
#   ('77', '4235'),
#   ('81', '7650'),
#   ('85', '3047'),
#   ('96', '7103')]}

# %%
"23"[0]

for elem in vertID_squareLoc_dict:
    print(vertID_squareLoc_dict[elem])
# Out:
# '2'

# %%
class Node:
    """
    A node class for A* Pathfinding
    """

    def __init__(self, parent=None, position=None):
        self.parent = parent
        self.position = position #the VertexID

        self.g = 0 #distance from current vertex to start
        self.h = 0 #distance from current vertex to goal -based upon heuristic
        self.f = 0 #effective cost of current vertex 

    def __eq__(self, other):
        return self.position == other.position
    
    def __repr__(self):
        return f"VertexID: ({self.position}) - g: {self.g} h: {self.h} f: {self.f}"

    # defining less than for purposes of heap queue
    def __lt__(self, other):
        return self.f < other.f
    
    # defining greater than for purposes of heap queue
    def __gt__(self, other):
        return self.f > other.f

# %%
def return_path(current_node):
    path = []
    current = current_node
    while current is not None:
        path.append(current.position)
        current = current.parent
    return path

# %%
def get_adj_verts(current_vert, vertex_adj_dict):
    
    #create a simple list of the verticies to search through
#     simp_list_adj_verts = []
#     for vert in vertex_adj_dict[current_vert]:
#         simp_list_adj_verts.append(vert[0])
        
#     return vertex_adj_dict[current_vert], simp_list_adj_verts
    return vertex_adj_dict[current_vert]

# %%
current_vert = "28"
b = get_adj_verts(current_vert, vertex_adj_dict)

b
# Out:
# [('0', '4683'),
#  ('2', '4229'),
#  ('7', '4826'),
#  ('19', '4242'),
#  ('24', '3771'),
#  ('33', '7153'),
#  ('48', '5592'),
#  ('63', '4835'),
#  ('64', '2394'),
#  ('65', '7162'),
#  ('66', '3228'),
#  ('71', '5163'),
#  ('74', '6645'),
#  ('80', '4389'),
#  ('81', '2985'),
#  ('90', '2662'),
#  ('91', '3939'),
#  ('92', '4466')]

# %%
def a_star(vertex_adj_dict, vertID_squareLoc_dict, dest, source):
    
    #create source node
    source_node = Node(None, int(vertID_squareLoc_dict[source]))
    source_node.g = source_node.h = source_node.f = 0
    print("SOURCE: ", source_node)
    
    #create dest node
    dest_node = Node(None, int(vertID_squareLoc_dict[dest]))
    dest_node.g = dest_node.h = dest_node.f = 0
    print("DEST: ", dest_node)
    
    # Initialize both open and closed list
    open_list = []
    closed_list = []
    
    closed_list_alt = []

    # Heapify the open_list and add the source to heap
    heapq.heapify(open_list) 
    heapq.heappush(open_list, source_node)

    # Adding a stop condition
    outer_iterations = 0
    max_iterations = 1000

    # Loop until you find the end
    while len(open_list) > 0:
        outer_iterations += 1
        print("\nWhile Loop Iters: ", outer_iterations, "\n")

        if outer_iterations > max_iterations:
            print("TOO MANY ITERATIONS?!!??")
            return return_path(current_vert)
        
        
        current_vert = heapq.heappop(open_list)
        print("current_vert: ",current_vert)
        
        #add the node to the closed list
        closed_list.append(current_vert)
        
        closed_list_alt.append(current_vert.position)
        
        #check if we made it to the destination
        if current_vert == dest_node:
            return return_path(current_vert)

        
        
        #collect children of the current vertex from data structures        
        current_verts_children = get_adj_verts(str(current_vert.position), vertex_adj_dict)
    
        children = []
        for child in current_verts_children:
            #check if the verticie is in the closed list

            if int(child[0]) not in closed_list_alt:
            
                #the parent and the vertexID start the node
                new_child = Node(current_vert, int(child[0]))

                #calculate g by using the exact distance from data_struct
                new_child.g = current_vert.g + int(child[1])

                #calculate h by finding the euclidian distance, knowing which square in the 10x10
                #the current node and the dest nodes are
                new_child.h = (int(vertID_squareLoc_dict[child[0]])**2) + (int(vertID_squareLoc_dict[dest])**2)

                children.append(new_child)
                
                new_child.f = new_child.g + new_child.h
                
                heapq.heappush(open_list, new_child)
            else:
                print("skipped")

# ////
            
#         print("children: ",children)
#         #cacluate the g, h, and f values for each child and place on heap
#         for child in children:
            
#             if (child.position) in closed_list_alt:
#                 print("closed list child: ",child.position)
                
                
#             else:
                
# #                 print(child)
#                 #add those nodes to the heap -> then keep going in while loop
                
                
            
#             #check if the child has already been explored
# #             if len([closed_child for closed_child in closed_list if closed_child == child]) > 0:
# #                 continue
            
#             #calculate f by summing g: distance traveled and h: expected distance yet to travel
# #             child.f = child.g + child.h
            
# #             print(child)
#             #add those nodes to the heap -> then keep going in while loop
# #             heapq.heappush(open_list, child)
        
#         print("\n\n\nCLOSED LIST: ")
#         for e in closed_list_alt:
#             print(e, type(e))
        
    #error out
    print("didn't work :(")

    return None

# %%
a_star(vertex_adj_dict, vertID_squareLoc_dict, dest, source)
# Out:
# SOURCE:  79 - g: 0 h: 0 f: 0
# DEST:  17 - g: 0 h: 0 f: 0
#
# While Loop Iters:  1
#
# current_vert:  79 - g: 0 h: 0 f: 0
#
# While Loop Iters:  2
#
# current_vert:  97 - g: 521 h: 773 f: 1294
# skipped
#
# While Loop Iters:  3
#
# current_vert:  44 - g: 675 h: 1313 f: 1988
# skipped
#
# While Loop Iters:  4
#
# current_vert:  80 - g: 1718 h: 433 f: 2151
# skipped
#
# While Loop Iters:  5
#
# current_vert:  26 - g: 2488 h: 458 f: 2946
# skipped
# skipped
#
# While Loop Iters:  6
#
# current_vert:  26 - g: 2551 h: 458 f: 3009
# skipped
# skipped
#
# While Loop Iters:  7
#
# current_vert:  84 - g: 3055 h: 290 f: 3345
# skipped
#
# While Loop Iters:  8
#
# current_vert:  42 - g: 2164 h: 1189 f: 3353
# skipped
#
# While Loop Iters:  9
#
# current_vert:  95 - g: 2720 h: 689 f: 3409
# skipped
# skipped
#
# While Loop Iters:  10
#
# current_vert:  11 - g: 2089 h: 1445 f: 3534
# skipped
# skipped
#
# While Loop Iters:  11
#
# current_vert:  16 - g: 3570 h: 298 f: 3868
# skipped
# skipped
# skipped
#
# While Loop Iters:  12
#
# current_vert:  20 - g: 2044 h: 1970 f: 4014
# skipped
# skipped
# skipped
#
# While Loop Iters:  13
#
# current_vert:  7 - g: 3310 h: 1250 f: 4560
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  14
#
# current_vert:  46 - g: 4405 h: 289 f: 4694
# skipped
# skipped
# skipped
#
# While Loop Iters:  15
#
# current_vert:  7 - g: 3528 h: 1250 f: 4778
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  16
#
# current_vert:  7 - g: 3585 h: 1250 f: 4835
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  17
#
# current_vert:  51 - g: 4636 h: 293 f: 4929
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  18
#
# current_vert:  51 - g: 4699 h: 293 f: 4992
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  19
#
# current_vert:  16 - g: 4725 h: 298 f: 5023
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  20
#
# current_vert:  74 - g: 4751 h: 289 f: 5040
# skipped
#
# While Loop Iters:  21
#
# current_vert:  46 - g: 4804 h: 289 f: 5093
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  22
#
# current_vert:  25 - g: 4867 h: 290 f: 5157
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  23
#
# current_vert:  93 - g: 3951 h: 1514 f: 5465
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  24
#
# current_vert:  25 - g: 5264 h: 290 f: 5554
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  25
#
# current_vert:  99 - g: 5022 h: 578 f: 5600
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  26
#
# current_vert:  58 - g: 2517 h: 3098 f: 5615
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  27
#
# current_vert:  11 - g: 4198 h: 1445 f: 5643
# skipped
# skipped
# skipped
#
# While Loop Iters:  28
#
# current_vert:  14 - g: 5136 h: 545 f: 5681
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  29
#
# current_vert:  14 - g: 5199 h: 545 f: 5744
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  30
#
# current_vert:  25 - g: 5481 h: 290 f: 5771
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  31
#
# current_vert:  60 - g: 5576 h: 338 f: 5914
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  32
#
# current_vert:  14 - g: 5401 h: 545 f: 5946
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  33
#
# current_vert:  25 - g: 5663 h: 290 f: 5953
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  34
#
# current_vert:  4 - g: 4047 h: 2053 f: 6100
# skipped
# skipped
# skipped
#
# While Loop Iters:  35
#
# current_vert:  51 - g: 5821 h: 293 f: 6114
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  36
#
# current_vert:  86 - g: 3340 h: 2789 f: 6129
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  37
#
# current_vert:  14 - g: 5589 h: 545 f: 6134
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  38
#
# current_vert:  51 - g: 5965 h: 293 f: 6258
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  39
#
# current_vert:  25 - g: 5988 h: 290 f: 6278
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  40
#
# current_vert:  45 - g: 4442 h: 1889 f: 6331
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  41
#
# current_vert:  46 - g: 6050 h: 289 f: 6339
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  42
#
# current_vert:  66 - g: 6019 h: 338 f: 6357
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  43
#
# current_vert:  37 - g: 5547 h: 818 f: 6365
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  44
#
# current_vert:  46 - g: 6113 h: 289 f: 6402
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  45
#
# current_vert:  60 - g: 6076 h: 338 f: 6414
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  46
#
# current_vert:  66 - g: 6082 h: 338 f: 6420
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  47
#
# current_vert:  99 - g: 5845 h: 578 f: 6423
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  48
#
# current_vert:  20 - g: 4472 h: 1970 f: 6442
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  49
#
# current_vert:  60 - g: 6109 h: 338 f: 6447
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  50
#
# current_vert:  51 - g: 6160 h: 293 f: 6453
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  51
#
# current_vert:  99 - g: 5908 h: 578 f: 6486
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  52
#
# current_vert:  25 - g: 6206 h: 290 f: 6496
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  53
#
# current_vert:  45 - g: 4629 h: 1889 f: 6518
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  54
#
# current_vert:  25 - g: 6263 h: 290 f: 6553
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  55
#
# current_vert:  37 - g: 5765 h: 818 f: 6583
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  56
#
# current_vert:  93 - g: 5094 h: 1514 f: 6608
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  57
#
# current_vert:  37 - g: 5822 h: 818 f: 6640
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  58
#
# current_vert:  5 - g: 5466 h: 1189 f: 6655
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  59
#
# current_vert:  66 - g: 6331 h: 338 f: 6669
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  60
#
# current_vert:  51 - g: 6378 h: 293 f: 6671
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  61
#
# current_vert:  12 - g: 4312 h: 2405 f: 6717
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  62
#
# current_vert:  51 - g: 6435 h: 293 f: 6728
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  63
#
# current_vert:  16 - g: 6564 h: 298 f: 6862
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  64
#
# current_vert:  66 - g: 6608 h: 338 f: 6946
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  65
#
# current_vert:  56 - g: 6658 h: 314 f: 6972
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  66
#
# current_vert:  55 - g: 5358 h: 1658 f: 7016
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  67
#
# current_vert:  27 - g: 6686 h: 353 f: 7039
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  68
#
# current_vert:  27 - g: 6749 h: 353 f: 7102
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  69
#
# current_vert:  45 - g: 5261 h: 1889 f: 7150
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  70
#
# current_vert:  95 - g: 6476 h: 689 f: 7165
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  71
#
# current_vert:  37 - g: 6359 h: 818 f: 7177
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  72
#
# current_vert:  95 - g: 6539 h: 689 f: 7228
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  73
#
# current_vert:  82 - g: 6158 h: 1073 f: 7231
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  74
#
# current_vert:  27 - g: 6951 h: 353 f: 7304
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  75
#
# current_vert:  66 - g: 6998 h: 338 f: 7336
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  76
#
# current_vert:  92 - g: 3105 h: 4258 f: 7363
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  77
#
# current_vert:  62 - g: 4095 h: 3205 f: 7300
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  78
#
# current_vert:  45 - g: 5491 h: 1889 f: 7380
# skipped
# skipped
# skipped
# skipped
# skipped
# While Loop Iters:  79
#
# current_vert:  4 - g: 5373 h: 2053 f: 7426
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  80
#
# current_vert:  60 - g: 7114 h: 338 f: 7452
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  81
#
# current_vert:  27 - g: 7138 h: 353 f: 7491
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  82
#
# current_vert:  27 - g: 7139 h: 353 f: 7492
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  83
#
# current_vert:  14 - g: 6978 h: 545 f: 7523
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  84
#
# current_vert:  62 - g: 4352 h: 3205 f: 7557
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  85
#
# current_vert:  18 - g: 6518 h: 1073 f: 7591
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  86
#
# current_vert:  48 - g: 3475 h: 4133 f: 7608
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  87
#
# current_vert:  18 - g: 6609 h: 1073 f: 7682
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  88
#
# current_vert:  28 - g: 6107 h: 1585 f: 7692
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  89
#
# current_vert:  5 - g: 6537 h: 1189 f: 7726
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  90
#
# current_vert:  92 - g: 3503 h: 4258 f: 7761
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  91
#
# current_vert:  92 - g: 3503 h: 4258 f: 7761
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  92
#
# current_vert:  56 - g: 7481 h: 314 f: 7795
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  93
#
# current_vert:  48 - g: 3667 h: 4133 f: 7800
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  94
#
# current_vert:  52 - g: 6749 h: 1073 f: 7822
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  95
#
# current_vert:  56 - g: 7544 h: 314 f: 7858
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  96
#
# current_vert:  10 - g: 7527 h: 353 f: 7880
# skipped
# skipped
#
# While Loop Iters:  97
#
# current_vert:  82 - g: 6814 h: 1073 f: 7887
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  98
#
# current_vert:  1 - g: 6837 h: 1073 f: 7910
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  99
#
# current_vert:  5 - g: 6742 h: 1189 f: 7931
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  100
#
# current_vert:  10 - g: 7590 h: 353 f: 7943
# skipped
# skipped
#
# While Loop Iters:  101
#
# current_vert:  10 - g: 7611 h: 353 f: 7964
# skipped
# skipped
#
# While Loop Iters:  102
#
# current_vert:  87 - g: 3716 h: 4258 f: 7974
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  103
#
# current_vert:  82 - g: 6913 h: 1073 f: 7986
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  104
#
# current_vert:  21 - g: 7337 h: 650 f: 7987
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
#
# While Loop Iters:  105
#
# current_vert:  17 - g: 7079 h: 914 f: 7993
# [17, 7, 42, 44, 79]

# %%
""" A Python Class
A simple Python graph class, demonstrating the essential 
facts and functionalities of graphs.
"""


class Graph(object):

    def __init__(self, graph_dict=None):
        """ initializes a graph object 
            If no dictionary or None is given, 
            an empty dictionary will be used
        """
        if graph_dict == None:
            graph_dict = {}
        self.__graph_dict = graph_dict

    def vertices(self):
        """ returns the vertices of a graph """
        return list(self.__graph_dict.keys())

    def edges(self):
        """ returns the edges of a graph """
        return self.__generate_edges()

    def add_vertex(self, vertex):
        """ If the vertex "vertex" is not in 
            self.__graph_dict, a key "vertex" with an empty
            list as a value is added to the dictionary. 
            Otherwise nothing has to be done. 
        """
        if vertex not in self.__graph_dict:
            self.__graph_dict[vertex] = []

    def add_edge(self, edge):
        """ assumes that edge is of type set, tuple or list; 
            between two vertices can be multiple edges! 
        """
        edge = set(edge)
        (vertex1, vertex2) = tuple(edge)
        if vertex1 in self.__graph_dict:
            self.__graph_dict[vertex1].append(vertex2)
        else:
            self.__graph_dict[vertex1] = [vertex2]

    def __generate_edges(self):
        """ A static method generating the edges of the 
            graph "graph". Edges are represented as sets 
            with one (a loop back to the vertex) or two 
            vertices 
        """
        edges = []
        for vertex in self.__graph_dict:
            for neighbour in self.__graph_dict[vertex]:
                if {neighbour, vertex} not in edges:
                    edges.append({vertex, neighbour})
        return edges

    def __str__(self):
        res = "vertices: "
        for k in self.__graph_dict:
            res += str(k) + " "
        res += "\nedges: "
        for edge in self.__generate_edges():
            res += str(edge) + " "
        return res


if __name__ == "__main__":

    g = { "a" : ["d"],
          "b" : ["c"],
          "c" : ["b", "c", "d", "e"],
          "d" : ["a", "c"],
          "e" : ["c"],
          "f" : []
        }


    graph = Graph(g)

    print("Vertices of graph:")
    print(graph.vertices())

    print("Edges of graph:")
    print(graph.edges())

    print("Add vertex:")
    graph.add_vertex("z")

    print("Vertices of graph:")
    print(graph.vertices())
 
    print("Add an edge:")
    graph.add_edge({"a","z"})
    
    print("Vertices of graph:")
    print(graph.vertices())

    print("Edges of graph:")
    print(graph.edges())

    print('Adding an edge {"x","y"} with new vertices:')
    graph.add_edge({"x","y"})
    print("Vertices of graph:")
    print(graph.vertices())
    print("Edges of graph:")
    print(graph.edges())
# Out:
# Vertices of graph:
# ['a', 'b', 'c', 'd', 'e', 'f']
# Edges of graph:
# [{'d', 'a'}, {'c', 'b'}, {'c'}, {'d', 'c'}, {'e', 'c'}]
# Add vertex:
# Vertices of graph:
# ['a', 'b', 'c', 'd', 'e', 'f', 'z']
# Add an edge:
# Vertices of graph:
# ['a', 'b', 'c', 'd', 'e', 'f', 'z']
# Edges of graph:
# [{'d', 'a'}, {'c', 'b'}, {'c'}, {'d', 'c'}, {'e', 'c'}, {'a', 'z'}]
# Adding an edge {"x","y"} with new vertices:
# Vertices of graph:
# ['a', 'b', 'c', 'd', 'e', 'f', 'z', 'y']
# Edges of graph:
# [{'d', 'a'}, {'c', 'b'}, {'c'}, {'d', 'c'}, {'e', 'c'}, {'a', 'z'}, {'y', 'x'}]

# %%
children = [1,2,3,4]
closed_list = [1,2]

for child in children:
    print(child)
    # Child is on the closed list
    if len([closed_child for closed_child in closed_list if closed_child == child]) > 0:
        continue
# Out:
# 1
# 2
# 3
# 4
